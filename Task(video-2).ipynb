# %%
#Libraries and Dependencies installations..

# !pip install -U ultralytics
# !pip install ultralytics==8.0.196 \
            deep-sort-realtime==1.3.2 \
            scenedetect==0.6.1 \
            opencv-python \
            numpy \
            psutil \
            GPUtil \
            torch \
            torchvision \
            torchaudio

# %%
import json, os, psutil, time, torch, GPUtil, platform
from datetime import datetime
import numpy as np
import cv2
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
from scenedetect import VideoManager, SceneManager
from scenedetect.detectors import ContentDetector
import subprocess

# -------- CONFIG --------
CONFIG = {
    "video_path": "/content/drive/MyDrive/Colab Notebooks/input_2.mp4",
    "output_path": "/content/drive/MyDrive/Colab Notebooks/test_output_2.mp4",
    "final_output_path": "/content/drive/MyDrive/Colab Notebooks/with ffmpeg work/test_output_2_final.mp4",  # after ffmpeg
    "target_classes_default": ["person", "car"],
    "yolo_model": "yolov8x.pt",
    "conf_threshold": 0.35,
    "nms_threshold": 0.5,
    "zoom_min": 2.2,
    "zoom_max": 3.4,
    "scene_threshold": 30.0,
    "output_resolution": (3840, 2160),  # 4K UHD
    "fps": 24,
    "deep_sort": {
        "max_age": 30,
        "n_init": 3,
        "max_iou_distance": 0.7
    },
    "yolo_batch_size": 4,
    "yolo_img_size": 640,
    "smoothing_factor": 0.2  # for EMA smoothing of pan/zoom
}

# -------- INIT MODELS --------
device = "cuda" if torch.cuda.is_available() else "cpu"
model = YOLO(CONFIG["yolo_model"])
model.to(device)
deepsort = DeepSort(
    max_age=CONFIG["deep_sort"]["max_age"],
    n_init=CONFIG["deep_sort"]["n_init"],
    max_iou_distance=CONFIG["deep_sort"]["max_iou_distance"]
)

# -------- UTILS --------
def detect_scenes(video_path, threshold):
    video_manager = VideoManager([video_path])
    scene_manager = SceneManager()
    scene_manager.add_detector(ContentDetector(threshold=threshold))
    video_manager.set_duration()
    video_manager.start()
    scene_manager.detect_scenes(frame_source=video_manager)
    scene_list = scene_manager.get_scene_list()
    video_manager.release()
    return [(int(start.get_frames()), int(end.get_frames())) for start, end in scene_list]

def crop_zoom(frame, center_x, center_y, zoom):
    h, w = frame.shape[:2]
    new_w, new_h = int(w / zoom), int(h / zoom)
    x1, y1 = max(0, center_x - new_w // 2), max(0, center_y - new_h // 2)
    x2, y2 = min(w, x1 + new_w), min(h, y1 + new_h)
    if x2 <= x1 or y2 <= y1:
        return frame
    return cv2.resize(frame[y1:y2, x1:x2], (w, h))

def get_hardware_info():
    gpu_info = GPUtil.getGPUs()[0] if torch.cuda.is_available() else None
    return {
        "cpu_physical_cores": psutil.cpu_count(logical=False),
        "cpu_logical_cores": psutil.cpu_count(logical=True),
        "gpu_name": gpu_info.name if gpu_info else "CPU",
        "gpu_memory_total_mb": gpu_info.memoryTotal if gpu_info else None,
        "ram_total_gb": round(psutil.virtual_memory().total / (1024**3), 2),
        "system": platform.system(),
        "python_version": platform.python_version()
    }

# Exponential Moving Average smoothing helper
def ema_smooth(prev, current, alpha):
    if prev is None:
        return current
    return alpha * current + (1 - alpha) * prev

# Placeholder: get per-scene target classes dynamically
def get_classes_for_scene(scene_idx):
    # Example: alternate scenes track only 'person', others track 'person' + 'car'
    if scene_idx % 2 == 0:
        return ["person"]
    else:
        return ["person", "car"]

# -------- MAIN PROCESS --------
def process_video():
    hw_info = get_hardware_info()
    cap = cv2.VideoCapture(CONFIG["video_path"])
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps_input = cap.get(cv2.CAP_PROP_FPS)

    writer = cv2.VideoWriter(CONFIG["output_path"], cv2.VideoWriter_fourcc(*"mp4v"), CONFIG["fps"], (width, height))
    scene_frames = detect_scenes(CONFIG["video_path"], CONFIG["scene_threshold"])
    print(f"Detected {len(scene_frames)} scenes.")

    print("Hardware info:", hw_info)
    print(f"Processing video {CONFIG['video_path']} at {width}x{height} px, input FPS: {fps_input}")

    # Tracking stats init
    frame_idx = 0
    start_time = time.time()
    prev_center = None
    prev_zoom = None
    zoom_values = []
    jitter_values = []
    missed_subjects = 0
    total_tracks = 0
    current_scene_idx = 0

    for scene_idx, (scene_start, scene_end) in enumerate(scene_frames):
        # Update target classes dynamically per scene
        target_classes = get_classes_for_scene(scene_idx)
        class_name_to_id = {name: idx for idx, name in model.names.items()}
        target_class_ids = [class_name_to_id.get(c) for c in target_classes if c in class_name_to_id]

        print(f"\nScene {scene_idx+1}/{len(scene_frames)} frames {scene_start}-{scene_end}: tracking classes {target_classes}")

        for f in range(scene_start, scene_end + 1):
            ret, frame = cap.read()
            if not ret:
                break

            # YOLO inference with batch size and img size (resize)
            img = cv2.resize(frame, (CONFIG["yolo_img_size"], CONFIG["yolo_img_size"]))
            results = model.predict(img, conf=CONFIG["conf_threshold"], device=device, verbose=False, batch=CONFIG["yolo_batch_size"])
            detections = results[0].boxes.data.cpu().numpy()

            track_inputs = []
            for *xyxy, conf, cls in detections:
                cls_id = int(cls)
                if cls_id in target_class_ids:
                    # Scale bbox back to original frame size
                    scale_x = width / CONFIG["yolo_img_size"]
                    scale_y = height / CONFIG["yolo_img_size"]
                    x1, y1, x2, y2 = map(int, [xyxy[0]*scale_x, xyxy[1]*scale_y, xyxy[2]*scale_x, xyxy[3]*scale_y])
                    track_inputs.append(([x1, y1, x2 - x1, y2 - y1], conf, model.names[cls_id]))

            tracks = deepsort.update_tracks(track_inputs, frame=frame)

            subjects = []
            for track in tracks:
                if not track.is_confirmed():
                    continue
                total_tracks += 1
                x1, y1, x2, y2 = map(int, track.to_ltrb())
                center_x, center_y = (x1 + x2) // 2, (y1 + y2) // 2
                area_ratio = ((x2 - x1) * (y2 - y1)) / (width * height)
                if area_ratio > 0:
                    zoom = np.clip(3.0 / area_ratio, CONFIG["zoom_min"], CONFIG["zoom_max"])
                    subjects.append((center_x, center_y, zoom))

            if subjects:
                avg_center_x = int(np.mean([s[0] for s in subjects]))
                avg_center_y = int(np.mean([s[1] for s in subjects]))
                avg_zoom_raw = np.mean([s[2] for s in subjects])
                # Smooth center and zoom
                avg_center_x = int(ema_smooth(prev_center[0] if prev_center else None, avg_center_x, CONFIG["smoothing_factor"]))
                avg_center_y = int(ema_smooth(prev_center[1] if prev_center else None, avg_center_y, CONFIG["smoothing_factor"]))
                avg_zoom = ema_smooth(prev_zoom, avg_zoom_raw, CONFIG["smoothing_factor"])
                prev_center = (avg_center_x, avg_center_y)
                prev_zoom = avg_zoom

                frame = crop_zoom(frame, avg_center_x, avg_center_y, avg_zoom)
                zoom_values.append(avg_zoom)

                # Jitter calc: distance between prev and current center
                if prev_center is not None and frame_idx > 0:
                    jitter = np.sqrt((avg_center_x - prev_center[0])**2 + (avg_center_y - prev_center[1])**2)
                    jitter_values.append(jitter)

                print(f"[Frame {frame_idx+1}/{total_frames}] Zoom: {avg_zoom:.2f} Center: ({avg_center_x},{avg_center_y})")
            else:
                missed_subjects += 1
                zoom_values.append(None)
                print(f"[Frame {frame_idx+1}/{total_frames}] No subjects detected")

            writer.write(frame)
            frame_idx += 1

    cap.release()
    writer.release()

    elapsed = time.time() - start_time
    avg_zoom = np.mean([z for z in zoom_values if z is not None]) if zoom_values else None
    avg_jitter = np.mean(jitter_values) if jitter_values else 0
    avg_fps = total_frames / elapsed if elapsed > 0 else 0

    print("\n=== Processing Summary ===")
    print(f"Total frames processed: {total_frames}")
    print(f"Total scenes detected: {len(scene_frames)}")
    print(f"Total processing time (seconds): {elapsed:.2f}")
    print(f"Average FPS: {avg_fps:.2f}")
    print(f"Average zoom level: {avg_zoom:.2f}" if avg_zoom else "No zoom data")
    print(f"Average jitter (pixels/frame): {avg_jitter:.2f}")
    print(f"Missed subjects frames: {missed_subjects}")
    print(f"Total confirmed tracks: {total_tracks}")

    # Call ffmpeg to enforce final format and audio encoding
    ffmpeg_cmd = [
        "ffmpeg", "-y", "-i", CONFIG["output_path"],
        "-c:v", "libx264",
        "-crf", "23",  # adjust as needed 18-28 range
        "-preset", "slow",
        "-r", str(CONFIG["fps"]),
        "-c:a", "aac",
        "-b:a", "320k",
        "-ac", "6",  # 5.1 or 7.1 audio layout can be tuned here
        CONFIG["final_output_path"]
    ]
    print("\nRunning ffmpeg to finalize output with codec and audio settings...")
    subprocess.run(ffmpeg_cmd, check=True)
    print(f"Final video saved at {CONFIG['final_output_path']}")

# ---- RUN THE PROCESS ----
process_video()
# Out:
# ERROR:pyscenedetect:VideoManager is deprecated and will be removed.
# INFO:pyscenedetect:Loaded 1 video, framerate: 23.976 FPS, resolution: 1920 x 1080
# INFO:pyscenedetect:Duration set, start: None, duration: None, end: None.
# INFO:pyscenedetect:Downscale factor set to 7, effective resolution: 274 x 154
# INFO:pyscenedetect:Detecting scenes...
# Detected 224 scenes.
# Hardware info: {'cpu_physical_cores': 1, 'cpu_logical_cores': 2, 'gpu_name': 'CPU', 'gpu_memory_total_mb': None, 'ram_total_gb': 12.67, 'system': 'Linux', 'python_version': '3.11.13'}
# Processing video /content/drive/MyDrive/Colab Notebooks/input_2.mp4 at 1920x1080 px, input FPS: 23.976023976023978
#
# Scene 1/224 frames 0-86: tracking classes ['person']
# [Frame 1/43149] No subjects detected
# [Frame 2/43149] No subjects detected
# [Frame 3/43149] Zoom: 3.40 Center: (1387,473)
# [Frame 4/43149] Zoom: 3.40 Center: (1391,473)
# [Frame 5/43149] Zoom: 3.40 Center: (1397,474)
# [Frame 6/43149] Zoom: 3.40 Center: (1405,475)
# [Frame 7/43149] Zoom: 3.40 Center: (1413,477)
# [Frame 8/43149] Zoom: 3.40 Center: (1423,480)
# [Frame 9/43149] Zoom: 3.40 Center: (1432,485)
# [Frame 10/43149] Zoom: 3.40 Center: (1441,491)
# [Frame 11/43149] Zoom: 3.40 Center: (1451,498)
# [Frame 12/43149] Zoom: 3.40 Center: (1461,507)
# [Frame 13/43149] Zoom: 3.40 Center: (1470,518)
# [Frame 14/43149] Zoom: 3.40 Center: (1481,531)
# [Frame 15/43149] Zoom: 3.40 Center: (1491,545)
# [Frame 16/43149] Zoom: 3.40 Center: (1500,560)
# [Frame 17/43149] Zoom: 3.40 Center: (1510,574)
# [Frame 18/43149] Zoom: 3.40 Center: (1519,588)
# [Frame 19/43149] Zoom: 3.40 Center: (1529,601)
# [Frame 20/43149] Zoom: 3.40 Center: (1539,614)
# [Frame 21/43149] Zoom: 3.40 Center: (1549,626)
# [Frame 22/43149] Zoom: 3.40 Center: (1559,638)
# [Frame 23/43149] Zoom: 3.40 Center: (1562,651)
# [Frame 24/43149] Zoom: 3.40 Center: (1565,662)
# [Frame 25/43149] Zoom: 3.40 Center: (1568,672)
# [Frame 26/43149] Zoom: 3.40 Center: (1571,682)
# [Frame 27/43149] Zoom: 3.40 Center: (1575,691)
# [Frame 28/43149] Zoom: 3.40 Center: (1579,699)
# [Frame 29/43149] Zoom: 3.40 Center: (1583,707)
# [Frame 30/43149] Zoom: 3.40 Center: (1587,715)
# [Frame 31/43149] Zoom: 3.40 Center: (1591,722)
# [Frame 32/43149] Zoom: 3.40 Center: (1595,729)
# [Frame 33/43149] Zoom: 3.40 Center: (1599,736)
# [Frame 34/43149] Zoom: 3.40 Center: (1603,743)
# [Frame 35/43149] Zoom: 3.40 Center: (1607,749)
# [Frame 36/43149] Zoom: 3.40 Center: (1611,756)
# [Frame 37/43149] Zoom: 3.40 Center: (1615,762)
# [Frame 38/43149] Zoom: 3.40 Center: (1619,768)
# [Frame 39/43149] Zoom: 3.40 Center: (1624,774)
# [Frame 40/43149] Zoom: 3.40 Center: (1628,780)
# [Frame 41/43149] Zoom: 3.40 Center: (1633,786)
# [Frame 42/43149] Zoom: 3.40 Center: (1637,793)
# [Frame 43/43149] Zoom: 3.40 Center: (1641,799)
# [Frame 44/43149] Zoom: 3.40 Center: (1645,805)
# [Frame 45/43149] Zoom: 3.40 Center: (1650,811)
# [Frame 46/43149] Zoom: 3.40 Center: (1655,817)
# [Frame 47/43149] Zoom: 3.40 Center: (1624,800)
# [Frame 48/43149] Zoom: 3.40 Center: (1599,787)
# [Frame 49/43149] Zoom: 3.40 Center: (1579,777)
# [Frame 50/43149] Zoom: 3.40 Center: (1563,769)
# [Frame 51/43149] Zoom: 3.40 Center: (1550,763)
# [Frame 52/43149] Zoom: 3.40 Center: (1539,758)
# [Frame 53/43149] Zoom: 3.40 Center: (1530,754)
# [Frame 54/43149] No subjects detected
# [Frame 55/43149] No subjects detected
# [Frame 56/43149] No subjects detected
# [Frame 57/43149] No subjects detected
# [Frame 58/43149] No subjects detected
# [Frame 59/43149] No subjects detected
# [Frame 60/43149] No subjects detected
# [Frame 61/43149] No subjects detected
# [Frame 62/43149] No subjects detected
# [Frame 63/43149] No subjects detected
# [Frame 64/43149] No subjects detected
# [Frame 65/43149] No subjects detected
# [Frame 66/43149] No subjects detected
# [Frame 67/43149] No subjects detected
# [Frame 68/43149] No subjects detected
# [Frame 69/43149] No subjects detected
# [Frame 70/43149] No subjects detected
# [Frame 71/43149] No subjects detected
# [Frame 72/43149] No subjects detected
# [Frame 73/43149] No subjects detected
# [Frame 74/43149] No subjects detected
# [Frame 75/43149] No subjects detected
# [Frame 76/43149] Zoom: 3.40 Center: (1497,745)
# [Frame 77/43149] Zoom: 3.40 Center: (1470,738)
# [Frame 78/43149] Zoom: 3.40 Center: (1449,732)
# [Frame 79/43149] Zoom: 3.40 Center: (1432,727)
# [Frame 80/43149] Zoom: 3.40 Center: (1418,723)
# [Frame 81/43149] Zoom: 3.40 Center: (1407,720)
# [Frame 82/43149] Zoom: 3.40 Center: (1399,716)
# [Frame 83/43149] Zoom: 3.40 Center: (1392,712)
# [Frame 84/43149] Zoom: 3.40 Center: (1387,708)
# [Frame 85/43149] Zoom: 3.40 Center: (1383,705)
# [Frame 86/43149] Zoom: 3.40 Center: (1380,702)
# [Frame 87/43149] Zoom: 3.40 Center: (1377,699)
#
# Scene 2/224 frames 86-130: tracking classes ['person', 'car']
# [Frame 88/43149] Zoom: 3.40 Center: (1375,697)
# [Frame 89/43149] Zoom: 3.40 Center: (1373,695)
# [Frame 90/43149] Zoom: 3.40 Center: (1363,691)
# [Frame 91/43149] Zoom: 3.40 Center: (1355,689)
# [Frame 92/43149] Zoom: 3.40 Center: (1311,686)
# [Frame 93/43149] Zoom: 3.40 Center: (1274,684)
# [Frame 94/43149] Zoom: 3.40 Center: (1244,683)
# [Frame 95/43149] Zoom: 3.40 Center: (1222,683)
# [Frame 96/43149] Zoom: 3.40 Center: (1204,683)
# [Frame 97/43149] Zoom: 3.40 Center: (1190,683)
# [Frame 98/43149] Zoom: 3.40 Center: (1178,684)
# [Frame 99/43149] Zoom: 3.40 Center: (1169,685)
# [Frame 100/43149] Zoom: 3.40 Center: (1161,686)
# [Frame 101/43149] Zoom: 3.40 Center: (1121,671)
# [Frame 102/43149] Zoom: 3.40 Center: (1125,676)
# [Frame 103/43149] Zoom: 3.40 Center: (1129,680)
# [Frame 104/43149] Zoom: 3.40 Center: (1132,684)
# [Frame 105/43149] Zoom: 3.40 Center: (1134,688)
# [Frame 106/43149] Zoom: 3.40 Center: (1136,691)
# [Frame 107/43149] Zoom: 3.40 Center: (1138,694)
# [Frame 108/43149] Zoom: 3.40 Center: (1140,697)
# [Frame 109/43149] Zoom: 3.40 Center: (1141,700)
# [Frame 110/43149] Zoom: 3.40 Center: (1142,702)
# [Frame 111/43149] Zoom: 3.40 Center: (1143,704)
# [Frame 112/43149] Zoom: 3.40 Center: (1144,706)
# [Frame 113/43149] Zoom: 3.40 Center: (1131,713)
# [Frame 114/43149] Zoom: 3.40 Center: (1120,719)
# [Frame 115/43149] Zoom: 3.40 Center: (1112,725)
# [Frame 116/43149] Zoom: 3.40 Center: (1105,730)
# [Frame 117/43149] Zoom: 3.40 Center: (1100,735)
# [Frame 118/43149] Zoom: 3.40 Center: (1096,740)
# [Frame 119/43149] Zoom: 3.40 Center: (1093,744)
# [Frame 120/43149] Zoom: 3.40 Center: (1091,748)
# [Frame 121/43149] Zoom: 3.40 Center: (1089,752)
# [Frame 122/43149] Zoom: 3.40 Center: (1088,754)
# [Frame 123/43149] Zoom: 3.40 Center: (1089,755)
# [Frame 124/43149] Zoom: 3.40 Center: (1090,728)
# [Frame 125/43149] Zoom: 3.40 Center: (1093,705)
# [Frame 126/43149] Zoom: 3.40 Center: (1098,686)
# [Frame 127/43149] Zoom: 3.40 Center: (1104,670)
# [Frame 128/43149] Zoom: 3.40 Center: (1111,656)
# [Frame 129/43149] Zoom: 3.40 Center: (1119,644)
# [Frame 130/43149] Zoom: 3.40 Center: (1128,633)
# [Frame 131/43149] Zoom: 3.40 Center: (1137,623)
# [Frame 132/43149] Zoom: 3.40 Center: (1147,615)
#
# Scene 3/224 frames 130-163: tracking classes ['person']
# [Frame 133/43149] Zoom: 3.40 Center: (1184,615)
# [Frame 134/43149] Zoom: 3.40 Center: (1218,613)
# [Frame 135/43149] Zoom: 3.40 Center: (1231,603)
# [Frame 136/43149] Zoom: 3.40 Center: (1247,594)
# [Frame 137/43149] Zoom: 3.40 Center: (1266,586)
# [Frame 138/43149] Zoom: 3.40 Center: (1287,578)
# [Frame 139/43149] Zoom: 3.39 Center: (1310,571)
# [Frame 140/43149] Zoom: 3.36 Center: (1335,564)
# [Frame 141/43149] Zoom: 3.32 Center: (1361,558)
# [Frame 142/43149] Zoom: 3.27 Center: (1388,552)
# [Frame 143/43149] Zoom: 3.22 Center: (1415,546)
# [Frame 144/43149] Zoom: 3.17 Center: (1443,540)
# [Frame 145/43149] Zoom: 3.12 Center: (1471,534)
# [Frame 146/43149] Zoom: 3.07 Center: (1500,528)
# [Frame 147/43149] Zoom: 3.02 Center: (1529,523)
# [Frame 148/43149] Zoom: 2.97 Center: (1558,518)
# [Frame 149/43149] Zoom: 2.94 Center: (1587,513)
# [Frame 150/43149] Zoom: 2.91 Center: (1617,508)
# [Frame 151/43149] Zoom: 2.89 Center: (1647,503)
# [Frame 152/43149] Zoom: 2.87 Center: (1677,498)
# [Frame 153/43149] Zoom: 2.86 Center: (1707,493)
# [Frame 154/43149] Zoom: 2.85 Center: (1737,488)
# [Frame 155/43149] Zoom: 2.96 Center: (1788,496)
# [Frame 156/43149] Zoom: 3.04 Center: (1836,503)
# [Frame 157/43149] Zoom: 3.12 Center: (1883,508)
# [Frame 158/43149] Zoom: 3.17 Center: (1928,512)
# [Frame 159/43149] Zoom: 3.22 Center: (1972,515)
# [Frame 160/43149] Zoom: 3.25 Center: (2016,518)
# [Frame 161/43149] Zoom: 3.28 Center: (2059,520)
# [Frame 162/43149] Zoom: 3.31 Center: (2101,521)
# [Frame 163/43149] Zoom: 3.33 Center: (2143,522)
# [Frame 164/43149] Zoom: 3.34 Center: (2184,523)
# [Frame 165/43149] Zoom: 3.35 Center: (2225,524)
# [Frame 166/43149] No subjects detected
#
# Scene 4/224 frames 163-308: tracking classes ['person', 'car']
# [Frame 167/43149] No subjects detected
# [Frame 168/43149] No subjects detected
# [Frame 169/43149] No subjects detected
# [Frame 170/43149] No subjects detected
# [Frame 171/43149] No subjects detected
# [Frame 172/43149] No subjects detected
# [Frame 173/43149] No subjects detected
# [Frame 174/43149] No subjects detected
# [Frame 175/43149] No subjects detected
# [Frame 176/43149] No subjects detected
# [Frame 177/43149] No subjects detected
# [Frame 178/43149] No subjects detected
# [Frame 179/43149] No subjects detected
# [Frame 180/43149] No subjects detected
# [Frame 181/43149] No subjects detected
# [Frame 182/43149] No subjects detected
# [Frame 183/43149] No subjects detected
# [Frame 184/43149] No subjects detected
# [Frame 185/43149] No subjects detected
# [Frame 186/43149] No subjects detected
# [Frame 187/43149] No subjects detected
# [Frame 188/43149] No subjects detected
# [Frame 189/43149] No subjects detected
# [Frame 190/43149] No subjects detected
# [Frame 191/43149] No subjects detected
# [Frame 192/43149] No subjects detected
# [Frame 193/43149] No subjects detected
# [Frame 194/43149] No subjects detected
# [Frame 195/43149] No subjects detected
# [Frame 196/43149] No subjects detected
# [Frame 197/43149] No subjects detected
# [Frame 198/43149] No subjects detected
# [Frame 199/43149] No subjects detected
# [Frame 200/43149] No subjects detected
# [Frame 201/43149] No subjects detected
# [Frame 202/43149] No subjects detected
# [Frame 203/43149] No subjects detected
# [Frame 204/43149] No subjects detected
# [Frame 205/43149] No subjects detected
# [Frame 206/43149] No subjects detected
# [Frame 207/43149] No subjects detected
# [Frame 208/43149] No subjects detected
# [Frame 209/43149] No subjects detected
# [Frame 210/43149] No subjects detected
# [Frame 211/43149] No subjects detected
# [Frame 212/43149] No subjects detected
# [Frame 213/43149] No subjects detected
# [Frame 214/43149] No subjects detected
# [Frame 215/43149] No subjects detected
# [Frame 216/43149] No subjects detected
# [Frame 217/43149] No subjects detected
# [Frame 218/43149] No subjects detected
# [Frame 219/43149] No subjects detected
# [Frame 220/43149] No subjects detected
# [Frame 221/43149] No subjects detected
# [Frame 222/43149] No subjects detected
# [Frame 223/43149] No subjects detected
# [Frame 224/43149] No subjects detected
# [Frame 225/43149] No subjects detected
# [Frame 226/43149] No subjects detected
# [Frame 227/43149] No subjects detected
# [Frame 228/43149] No subjects detected
# [Frame 229/43149] No subjects detected
# [Frame 230/43149] No subjects detected
# [Frame 231/43149] No subjects detected
# [Frame 232/43149] No subjects detected
# [Frame 233/43149] No subjects detected
# [Frame 234/43149] No subjects detected
# [Frame 235/43149] No subjects detected
# [Frame 236/43149] No subjects detected
# [Frame 237/43149] No subjects detected
# [Frame 238/43149] No subjects detected
# [Frame 239/43149] No subjects detected
# [Frame 240/43149] No subjects detected
# [Frame 241/43149] No subjects detected
# [Frame 242/43149] No subjects detected
# [Frame 243/43149] No subjects detected
# [Frame 244/43149] No subjects detected
# [Frame 245/43149] No subjects detected
# [Frame 246/43149] No subjects detected
# [Frame 247/43149] No subjects detected
# [Frame 248/43149] No subjects detected
# [Frame 249/43149] No subjects detected
# [Frame 250/43149] No subjects detected
# [Frame 251/43149] No subjects detected
# [Frame 252/43149] No subjects detected
# [Frame 253/43149] No subjects detected
# [Frame 254/43149] No subjects detected
# [Frame 255/43149] No subjects detected
# [Frame 256/43149] No subjects detected
# [Frame 257/43149] No subjects detected
# [Frame 258/43149] No subjects detected
# [Frame 259/43149] No subjects detected
# [Frame 260/43149] No subjects detected
# [Frame 261/43149] No subjects detected
# [Frame 262/43149] No subjects detected
# [Frame 263/43149] No subjects detected
# [Frame 264/43149] No subjects detected
# [Frame 265/43149] No subjects detected
# [Frame 266/43149] No subjects detected
# [Frame 267/43149] No subjects detected
# [Frame 268/43149] No subjects detected
# [Frame 269/43149] No subjects detected
# [Frame 270/43149] No subjects detected
# [Frame 271/43149] No subjects detected
# [Frame 272/43149] No subjects detected
# [Frame 273/43149] No subjects detected
# [Frame 274/43149] No subjects detected
# [Frame 275/43149] No subjects detected
# [Frame 276/43149] No subjects detected
# [Frame 277/43149] No subjects detected
# [Frame 278/43149] No subjects detected
# [Frame 279/43149] No subjects detected
# [Frame 280/43149] No subjects detected
# [Frame 281/43149] No subjects detected
# [Frame 282/43149] No subjects detected
# [Frame 283/43149] No subjects detected
# [Frame 284/43149] No subjects detected
# [Frame 285/43149] No subjects detected
# [Frame 286/43149] No subjects detected
# [Frame 287/43149] No subjects detected
# [Frame 288/43149] No subjects detected
# [Frame 289/43149] No subjects detected
# [Frame 290/43149] No subjects detected
# [Frame 291/43149] No subjects detected
# [Frame 292/43149] No subjects detected
# [Frame 293/43149] No subjects detected
# [Frame 294/43149] No subjects detected
# [Frame 295/43149] No subjects detected
# [Frame 296/43149] No subjects detected
# [Frame 297/43149] No subjects detected
# [Frame 298/43149] No subjects detected
# [Frame 299/43149] No subjects detected
# [Frame 300/43149] No subjects detected
# [Frame 301/43149] No subjects detected
# [Frame 302/43149] No subjects detected
# [Frame 303/43149] No subjects detected
# [Frame 304/43149] No subjects detected
# [Frame 305/43149] No subjects detected
# [Frame 306/43149] No subjects detected
# [Frame 307/43149] No subjects detected
# [Frame 308/43149] No subjects detected
# [Frame 309/43149] No subjects detected
# [Frame 310/43149] No subjects detected
# [Frame 311/43149] No subjects detected
# [Frame 312/43149] No subjects detected
#
# Scene 5/224 frames 308-329: tracking classes ['person']
# [Frame 313/43149] No subjects detected
# [Frame 314/43149] No subjects detected
# [Frame 315/43149] No subjects detected
# [Frame 316/43149] No subjects detected
# [Frame 317/43149] No subjects detected
# [Frame 318/43149] No subjects detected
# [Frame 319/43149] No subjects detected
# [Frame 320/43149] No subjects detected
# [Frame 321/43149] No subjects detected
# [Frame 322/43149] No subjects detected
# [Frame 323/43149] No subjects detected
# [Frame 324/43149] No subjects detected
# [Frame 325/43149] No subjects detected
# [Frame 326/43149] No subjects detected
# [Frame 327/43149] No subjects detected
# [Frame 328/43149] No subjects detected
# [Frame 329/43149] No subjects detected
# [Frame 330/43149] No subjects detected
# [Frame 331/43149] No subjects detected
# [Frame 332/43149] Zoom: 3.36 Center: (1960,518)
# [Frame 333/43149] Zoom: 3.37 Center: (1750,511)
# [Frame 334/43149] Zoom: 3.38 Center: (1586,503)
#
# Scene 6/224 frames 329-346: tracking classes ['person', 'car']
# [Frame 335/43149] Zoom: 3.38 Center: (1454,496)
# [Frame 336/43149] Zoom: 3.38 Center: (1351,491)
# [Frame 337/43149] Zoom: 3.39 Center: (1271,496)
# [Frame 338/43149] Zoom: 3.39 Center: (1211,502)
# [Frame 339/43149] Zoom: 3.39 Center: (1166,508)
# [Frame 340/43149] Zoom: 3.39 Center: (1133,514)
# [Frame 341/43149] Zoom: 3.39 Center: (1110,520)
# [Frame 342/43149] Zoom: 3.40 Center: (1095,524)
# [Frame 343/43149] Zoom: 3.40 Center: (1086,527)
# [Frame 344/43149] Zoom: 3.40 Center: (1082,529)
# [Frame 345/43149] Zoom: 3.40 Center: (1082,530)
# [Frame 346/43149] Zoom: 3.40 Center: (1085,531)
# [Frame 347/43149] Zoom: 3.40 Center: (1090,532)
# [Frame 348/43149] Zoom: 3.40 Center: (1097,533)
# [Frame 349/43149] Zoom: 3.40 Center: (1124,514)
# [Frame 350/43149] Zoom: 3.40 Center: (1146,499)
# [Frame 351/43149] Zoom: 3.40 Center: (1163,487)
# [Frame 352/43149] Zoom: 3.40 Center: (1202,477)
#
# Scene 7/224 frames 346-388: tracking classes ['person']
# [Frame 353/43149] Zoom: 3.40 Center: (1233,469)
# [Frame 354/43149] Zoom: 3.40 Center: (1258,463)
# [Frame 355/43149] Zoom: 3.40 Center: (1278,458)
# [Frame 356/43149] Zoom: 3.40 Center: (1294,454)
# [Frame 357/43149] Zoom: 3.40 Center: (1307,450)
# [Frame 358/43149] Zoom: 3.40 Center: (1317,447)
# [Frame 359/43149] Zoom: 3.40 Center: (1325,444)
# [Frame 360/43149] Zoom: 3.40 Center: (1331,442)
# [Frame 361/43149] Zoom: 3.40 Center: (1336,440)
# [Frame 362/43149] Zoom: 3.40 Center: (1340,438)
# [Frame 363/43149] Zoom: 3.40 Center: (1343,437)
# [Frame 364/43149] Zoom: 3.40 Center: (1345,436)
# [Frame 365/43149] Zoom: 3.40 Center: (1347,435)
# [Frame 366/43149] Zoom: 3.40 Center: (1348,434)
# [Frame 367/43149] Zoom: 3.40 Center: (1349,433)
# [Frame 368/43149] Zoom: 3.40 Center: (1350,432)
# [Frame 369/43149] Zoom: 3.40 Center: (1351,431)
# [Frame 370/43149] Zoom: 3.40 Center: (1351,430)
# [Frame 371/43149] Zoom: 3.40 Center: (1351,429)
# [Frame 372/43149] Zoom: 3.40 Center: (1351,428)
# [Frame 373/43149] Zoom: 3.40 Center: (1366,415)
# [Frame 374/43149] Zoom: 3.40 Center: (1378,404)
# [Frame 375/43149] Zoom: 3.40 Center: (1387,395)
# [Frame 376/43149] Zoom: 3.40 Center: (1394,387)
# [Frame 377/43149] Zoom: 3.40 Center: (1365,378)
# [Frame 378/43149] Zoom: 3.40 Center: (1340,370)
# [Frame 379/43149] Zoom: 3.40 Center: (1318,364)
# [Frame 380/43149] Zoom: 3.40 Center: (1299,359)
# [Frame 381/43149] Zoom: 3.40 Center: (1282,354)
# [Frame 382/43149] Zoom: 3.40 Center: (1266,350)
# [Frame 383/43149] No subjects detected
# [Frame 384/43149] No subjects detected
# [Frame 385/43149] No subjects detected
# [Frame 386/43149] No subjects detected
# [Frame 387/43149] No subjects detected
# [Frame 388/43149] No subjects detected
# [Frame 389/43149] No subjects detected
# [Frame 390/43149] No subjects detected
# [Frame 391/43149] No subjects detected
# [Frame 392/43149] No subjects detected
# [Frame 393/43149] No subjects detected
# [Frame 394/43149] No subjects detected
# [Frame 395/43149] No subjects detected
#
# Scene 8/224 frames 388-423: tracking classes ['person', 'car']
# [Frame 396/43149] No subjects detected
# [Frame 397/43149] No subjects detected
# [Frame 398/43149] No subjects detected
# [Frame 399/43149] No subjects detected
# [Frame 400/43149] Zoom: 3.40 Center: (1115,425)
# [Frame 401/43149] Zoom: 3.40 Center: (977,486)
# [Frame 402/43149] Zoom: 3.40 Center: (867,537)
# [Frame 403/43149] Zoom: 3.40 Center: (781,580)
# [Frame 404/43149] Zoom: 3.40 Center: (703,615)
# [Frame 405/43149] Zoom: 3.40 Center: (642,645)
# [Frame 406/43149] Zoom: 3.40 Center: (594,671)
# [Frame 407/43149] Zoom: 3.40 Center: (557,694)
# [Frame 408/43149] Zoom: 3.40 Center: (529,715)
# [Frame 409/43149] Zoom: 3.40 Center: (507,733)
# [Frame 410/43149] Zoom: 3.40 Center: (491,749)
# [Frame 411/43149] Zoom: 3.40 Center: (480,764)
# [Frame 412/43149] Zoom: 3.40 Center: (472,778)
# [Frame 413/43149] Zoom: 3.40 Center: (467,790)
# [Frame 414/43149] Zoom: 3.40 Center: (456,801)
# [Frame 415/43149] Zoom: 3.40 Center: (459,812)
# [Frame 416/43149] Zoom: 3.40 Center: (463,821)
# [Frame 417/43149] Zoom: 3.40 Center: (467,830)
# [Frame 418/43149] Zoom: 3.40 Center: (471,838)
# [Frame 419/43149] Zoom: 3.40 Center: (475,845)
# [Frame 420/43149] Zoom: 3.40 Center: (479,851)
# [Frame 421/43149] Zoom: 3.40 Center: (483,857)
# [Frame 422/43149] Zoom: 3.40 Center: (487,862)
# [Frame 423/43149] Zoom: 3.40 Center: (492,867)
# [Frame 424/43149] Zoom: 3.40 Center: (497,872)
# [Frame 425/43149] Zoom: 3.40 Center: (502,877)
# [Frame 426/43149] Zoom: 3.40 Center: (557,865)
# [Frame 427/43149] Zoom: 3.40 Center: (602,856)
# [Frame 428/43149] Zoom: 3.40 Center: (638,849)
# [Frame 429/43149] Zoom: 3.40 Center: (667,844)
# [Frame 430/43149] Zoom: 3.40 Center: (691,841)
# [Frame 431/43149] Zoom: 3.40 Center: (710,839)
#
# Scene 9/224 frames 423-513: tracking classes ['person']
# [Frame 432/43149] Zoom: 3.40 Center: (726,838)
# [Frame 433/43149] Zoom: 3.40 Center: (739,837)
# [Frame 434/43149] Zoom: 3.40 Center: (755,835)
# [Frame 435/43149] Zoom: 3.40 Center: (768,833)
# [Frame 436/43149] Zoom: 3.40 Center: (779,832)
# [Frame 437/43149] Zoom: 3.40 Center: (788,832)
# [Frame 438/43149] Zoom: 3.40 Center: (797,826)
# [Frame 439/43149] Zoom: 3.40 Center: (804,821)
# [Frame 440/43149] Zoom: 3.40 Center: (810,818)
# [Frame 441/43149] Zoom: 3.40 Center: (815,815)
# [Frame 442/43149] Zoom: 3.40 Center: (819,813)
# [Frame 443/43149] Zoom: 3.40 Center: (823,812)
# [Frame 444/43149] Zoom: 3.40 Center: (826,811)
# [Frame 445/43149] Zoom: 3.40 Center: (829,810)
# [Frame 446/43149] Zoom: 3.40 Center: (831,810)
# [Frame 447/43149] Zoom: 3.40 Center: (833,810)
# [Frame 448/43149] Zoom: 3.40 Center: (835,810)
# [Frame 449/43149] Zoom: 3.40 Center: (837,810)
# [Frame 450/43149] Zoom: 3.40 Center: (839,810)
# [Frame 451/43149] Zoom: 3.40 Center: (840,811)
# [Frame 452/43149] Zoom: 3.40 Center: (841,811)
# [Frame 453/43149] Zoom: 3.40 Center: (843,812)
# [Frame 454/43149] Zoom: 3.40 Center: (873,797)
# [Frame 455/43149] Zoom: 3.40 Center: (897,785)
# [Frame 456/43149] Zoom: 3.40 Center: (916,775)
# [Frame 457/43149] Zoom: 3.40 Center: (931,767)
# [Frame 458/43149] Zoom: 3.40 Center: (943,761)
# [Frame 459/43149] Zoom: 3.40 Center: (952,756)
# [Frame 460/43149] Zoom: 3.40 Center: (959,752)
# [Frame 461/43149] Zoom: 3.40 Center: (964,749)
# [Frame 462/43149] No subjects detected
# [Frame 463/43149] No subjects detected
# [Frame 464/43149] No subjects detected
# [Frame 465/43149] No subjects detected
# [Frame 466/43149] No subjects detected
# [Frame 467/43149] No subjects detected
# [Frame 468/43149] No subjects detected
# [Frame 469/43149] No subjects detected
# [Frame 470/43149] No subjects detected
# [Frame 471/43149] No subjects detected
# [Frame 472/43149] No subjects detected
# [Frame 473/43149] No subjects detected
# [Frame 474/43149] No subjects detected
# [Frame 475/43149] No subjects detected
# [Frame 476/43149] No subjects detected
# [Frame 477/43149] No subjects detected
# [Frame 478/43149] No subjects detected
# [Frame 479/43149] No subjects detected
# [Frame 480/43149] No subjects detected
# [Frame 481/43149] No subjects detected
# [Frame 482/43149] No subjects detected
# [Frame 483/43149] No subjects detected
# [Frame 484/43149] No subjects detected
# [Frame 485/43149] No subjects detected
# [Frame 486/43149] No subjects detected
# [Frame 487/43149] No subjects detected
# [Frame 488/43149] No subjects detected
# [Frame 489/43149] No subjects detected
# [Frame 490/43149] No subjects detected
# [Frame 491/43149] No subjects detected
# [Frame 492/43149] No subjects detected
# [Frame 493/43149] No subjects detected
# [Frame 494/43149] No subjects detected
# [Frame 495/43149] No subjects detected
# [Frame 496/43149] No subjects detected
# [Frame 497/43149] No subjects detected
# [Frame 498/43149] No subjects detected
# [Frame 499/43149] No subjects detected
# [Frame 500/43149] No subjects detected
# [Frame 501/43149] No subjects detected
# [Frame 502/43149] No subjects detected
# [Frame 503/43149] No subjects detected
# [Frame 504/43149] No subjects detected
# [Frame 505/43149] No subjects detected
# [Frame 506/43149] No subjects detected
# [Frame 507/43149] No subjects detected
# [Frame 508/43149] No subjects detected
# [Frame 509/43149] No subjects detected
# [Frame 510/43149] No subjects detected
# [Frame 511/43149] No subjects detected
# [Frame 512/43149] No subjects detected
# [Frame 513/43149] No subjects detected
# [Frame 514/43149] No subjects detected
# [Frame 515/43149] No subjects detected
# [Frame 516/43149] Zoom: 3.40 Center: (923,683)
# [Frame 517/43149] Zoom: 3.40 Center: (888,631)
# [Frame 518/43149] Zoom: 3.40 Center: (857,589)
# [Frame 519/43149] Zoom: 3.40 Center: (831,555)
# [Frame 520/43149] Zoom: 3.40 Center: (808,528)
# [Frame 521/43149] Zoom: 3.40 Center: (787,507)
# [Frame 522/43149] Zoom: 3.40 Center: (769,491)
#
# Scene 10/224 frames 513-557: tracking classes ['person', 'car']
# [Frame 523/43149] Zoom: 3.40 Center: (752,478)
# [Frame 524/43149] Zoom: 3.40 Center: (737,468)
# [Frame 525/43149] Zoom: 3.40 Center: (709,491)
# [Frame 526/43149] Zoom: 3.40 Center: (685,510)
# [Frame 527/43149] Zoom: 3.40 Center: (665,525)
# [Frame 528/43149] Zoom: 3.40 Center: (648,538)
# [Frame 529/43149] Zoom: 3.40 Center: (633,548)
# [Frame 530/43149] Zoom: 3.40 Center: (620,557)
# [Frame 531/43149] Zoom: 3.40 Center: (609,564)
# [Frame 532/43149] Zoom: 3.40 Center: (599,570)
# [Frame 533/43149] Zoom: 3.40 Center: (589,575)
# [Frame 534/43149] Zoom: 3.40 Center: (580,580)
# [Frame 535/43149] Zoom: 3.40 Center: (570,584)
# [Frame 536/43149] Zoom: 3.40 Center: (560,587)
# [Frame 537/43149] Zoom: 3.40 Center: (551,590)
# [Frame 538/43149] Zoom: 3.40 Center: (543,593)
# [Frame 539/43149] Zoom: 3.40 Center: (536,595)
# [Frame 540/43149] Zoom: 3.40 Center: (528,597)
# [Frame 541/43149] Zoom: 3.40 Center: (501,609)
# [Frame 542/43149] Zoom: 3.40 Center: (478,619)
# [Frame 543/43149] Zoom: 3.40 Center: (458,628)
# [Frame 544/43149] Zoom: 3.40 Center: (442,636)
# [Frame 545/43149] Zoom: 3.40 Center: (428,644)
# [Frame 546/43149] Zoom: 3.40 Center: (416,651)
# [Frame 547/43149] Zoom: 3.40 Center: (405,657)
# [Frame 548/43149] Zoom: 3.40 Center: (395,662)
# [Frame 549/43149] Zoom: 3.40 Center: (386,667)
# [Frame 550/43149] Zoom: 3.40 Center: (378,671)
# [Frame 551/43149] Zoom: 3.40 Center: (371,675)
# [Frame 552/43149] Zoom: 3.40 Center: (364,678)
# [Frame 553/43149] Zoom: 3.40 Center: (357,681)
# [Frame 554/43149] Zoom: 3.40 Center: (351,684)
# [Frame 555/43149] Zoom: 3.40 Center: (345,687)
# [Frame 556/43149] Zoom: 3.40 Center: (339,690)
# [Frame 557/43149] Zoom: 3.40 Center: (334,694)
# [Frame 558/43149] Zoom: 3.40 Center: (334,692)
# [Frame 559/43149] Zoom: 3.40 Center: (336,689)
# [Frame 560/43149] Zoom: 3.40 Center: (336,686)
# [Frame 561/43149] Zoom: 3.40 Center: (335,684)
# [Frame 562/43149] Zoom: 3.40 Center: (333,683)
# [Frame 563/43149] Zoom: 3.40 Center: (330,682)
# [Frame 564/43149] Zoom: 3.40 Center: (322,681)
# [Frame 565/43149] Zoom: 3.40 Center: (316,681)
# [Frame 566/43149] Zoom: 3.40 Center: (339,673)
# [Frame 567/43149] Zoom: 3.40 Center: (356,667)
#
# Scene 11/224 frames 557-573: tracking classes ['person']
# [Frame 568/43149] Zoom: 3.40 Center: (368,662)
# [Frame 569/43149] Zoom: 3.40 Center: (376,658)
# [Frame 570/43149] Zoom: 3.40 Center: (379,656)
# [Frame 571/43149] Zoom: 3.40 Center: (381,656)
# [Frame 572/43149] Zoom: 3.40 Center: (381,657)
# [Frame 573/43149] Zoom: 3.40 Center: (380,658)
# [Frame 574/43149] Zoom: 3.40 Center: (378,659)
# [Frame 575/43149] Zoom: 3.40 Center: (435,621)
# [Frame 576/43149] Zoom: 3.40 Center: (479,590)
# [Frame 577/43149] Zoom: 3.40 Center: (514,565)
# [Frame 578/43149] Zoom: 3.40 Center: (607,541)
# [Frame 579/43149] Zoom: 3.40 Center: (681,521)
# [Frame 580/43149] Zoom: 3.40 Center: (740,504)
# [Frame 581/43149] Zoom: 3.40 Center: (787,490)
# [Frame 582/43149] Zoom: 3.40 Center: (824,478)
# [Frame 583/43149] Zoom: 3.40 Center: (854,468)
# [Frame 584/43149] Zoom: 3.40 Center: (877,459)
#
# Scene 12/224 frames 573-591: tracking classes ['person', 'car']
# [Frame 585/43149] Zoom: 3.40 Center: (895,452)
# [Frame 586/43149] Zoom: 3.40 Center: (909,446)
# [Frame 587/43149] Zoom: 3.40 Center: (920,440)
# [Frame 588/43149] Zoom: 3.40 Center: (929,435)
# [Frame 589/43149] Zoom: 3.40 Center: (936,430)
# [Frame 590/43149] Zoom: 3.40 Center: (941,426)
# [Frame 591/43149] Zoom: 3.40 Center: (944,422)
# [Frame 592/43149] Zoom: 3.40 Center: (947,418)
# [Frame 593/43149] Zoom: 3.40 Center: (949,414)
# [Frame 594/43149] Zoom: 3.40 Center: (950,411)
# [Frame 595/43149] Zoom: 3.40 Center: (950,408)
# [Frame 596/43149] Zoom: 3.40 Center: (950,405)
# [Frame 597/43149] Zoom: 3.40 Center: (950,402)
# [Frame 598/43149] Zoom: 3.40 Center: (949,399)
# [Frame 599/43149] Zoom: 3.40 Center: (948,396)
# [Frame 600/43149] Zoom: 3.40 Center: (947,393)
# [Frame 601/43149] Zoom: 3.40 Center: (946,390)
# [Frame 602/43149] Zoom: 3.40 Center: (945,387)
# [Frame 603/43149] Zoom: 3.40 Center: (944,384)
#
# Scene 13/224 frames 591-606: tracking classes ['person']
# [Frame 604/43149] No subjects detected
# [Frame 605/43149] No subjects detected
# [Frame 606/43149] No subjects detected
# [Frame 607/43149] No subjects detected
# [Frame 608/43149] No subjects detected
# [Frame 609/43149] No subjects detected
# [Frame 610/43149] No subjects detected
# [Frame 611/43149] No subjects detected
# [Frame 612/43149] No subjects detected
# [Frame 613/43149] No subjects detected
# [Frame 614/43149] No subjects detected
# [Frame 615/43149] No subjects detected
# [Frame 616/43149] No subjects detected
# [Frame 617/43149] No subjects detected
# [Frame 618/43149] No subjects detected
# [Frame 619/43149] No subjects detected
#
# Scene 14/224 frames 606-692: tracking classes ['person', 'car']
# [Frame 620/43149] No subjects detected
# [Frame 621/43149] No subjects detected
# [Frame 622/43149] No subjects detected
# [Frame 623/43149] No subjects detected
# [Frame 624/43149] No subjects detected
# [Frame 625/43149] No subjects detected
# [Frame 626/43149] No subjects detected
# [Frame 627/43149] No subjects detected
# [Frame 628/43149] No subjects detected
# [Frame 629/43149] No subjects detected
# [Frame 630/43149] No subjects detected
# [Frame 631/43149] No subjects detected
# [Frame 632/43149] No subjects detected
# [Frame 633/43149] No subjects detected
# [Frame 634/43149] No subjects detected
# [Frame 635/43149] No subjects detected
# [Frame 636/43149] No subjects detected
# [Frame 637/43149] No subjects detected
# [Frame 638/43149] No subjects detected
# [Frame 639/43149] No subjects detected
# [Frame 640/43149] No subjects detected
# [Frame 641/43149] No subjects detected
# [Frame 642/43149] Zoom: 3.40 Center: (1008,463)
# [Frame 643/43149] Zoom: 3.40 Center: (1063,523)
# [Frame 644/43149] Zoom: 3.40 Center: (1111,569)
# [Frame 645/43149] Zoom: 3.40 Center: (1153,603)
# [Frame 646/43149] Zoom: 3.40 Center: (1148,620)
# [Frame 647/43149] Zoom: 3.40 Center: (1129,629)
# [Frame 648/43149] Zoom: 3.40 Center: (1114,629)
# [Frame 649/43149] Zoom: 3.40 Center: (1100,626)
# [Frame 650/43149] Zoom: 3.40 Center: (1087,621)
# [Frame 651/43149] Zoom: 3.40 Center: (1074,616)
# [Frame 652/43149] Zoom: 3.40 Center: (1060,610)
# [Frame 653/43149] Zoom: 3.40 Center: (1046,604)
# [Frame 654/43149] Zoom: 3.40 Center: (1031,597)
# [Frame 655/43149] Zoom: 3.40 Center: (1015,590)
# [Frame 656/43149] Zoom: 3.40 Center: (999,583)
# [Frame 657/43149] Zoom: 3.40 Center: (983,576)
# [Frame 658/43149] Zoom: 3.40 Center: (995,572)
# [Frame 659/43149] Zoom: 3.40 Center: (984,571)
# [Frame 660/43149] Zoom: 3.40 Center: (971,568)
# [Frame 661/43149] Zoom: 3.40 Center: (957,564)
# [Frame 662/43149] Zoom: 3.40 Center: (944,559)
# [Frame 663/43149] Zoom: 3.40 Center: (930,553)
# [Frame 664/43149] Zoom: 3.40 Center: (916,546)
# [Frame 665/43149] Zoom: 3.40 Center: (902,538)
# [Frame 666/43149] Zoom: 3.40 Center: (888,530)
# [Frame 667/43149] Zoom: 3.40 Center: (877,525)
# [Frame 668/43149] Zoom: 3.40 Center: (866,520)
# [Frame 669/43149] Zoom: 3.40 Center: (854,514)
# [Frame 670/43149] Zoom: 3.40 Center: (842,508)
# [Frame 671/43149] Zoom: 3.40 Center: (829,501)
# [Frame 672/43149] Zoom: 3.40 Center: (816,494)
# [Frame 673/43149] Zoom: 3.40 Center: (803,487)
# [Frame 674/43149] Zoom: 3.40 Center: (790,479)
# [Frame 675/43149] Zoom: 3.40 Center: (777,471)
# [Frame 676/43149] Zoom: 3.40 Center: (765,463)
# [Frame 677/43149] Zoom: 3.40 Center: (753,454)
# [Frame 678/43149] Zoom: 3.40 Center: (706,450)
# [Frame 679/43149] Zoom: 3.40 Center: (657,452)
# [Frame 680/43149] Zoom: 3.40 Center: (628,460)
# [Frame 681/43149] Zoom: 3.40 Center: (632,486)
# [Frame 682/43149] Zoom: 3.40 Center: (634,507)
# [Frame 683/43149] Zoom: 3.40 Center: (634,523)
# [Frame 684/43149] Zoom: 3.40 Center: (631,536)
# [Frame 685/43149] Zoom: 3.40 Center: (627,547)
# [Frame 686/43149] Zoom: 3.40 Center: (622,556)
# [Frame 687/43149] Zoom: 3.40 Center: (615,563)
# [Frame 688/43149] Zoom: 3.40 Center: (606,569)
# [Frame 689/43149] Zoom: 3.40 Center: (596,574)
# [Frame 690/43149] Zoom: 3.40 Center: (587,577)
# [Frame 691/43149] Zoom: 3.40 Center: (577,581)
# [Frame 692/43149] Zoom: 3.40 Center: (568,583)
# [Frame 693/43149] Zoom: 3.40 Center: (560,586)
# [Frame 694/43149] Zoom: 3.40 Center: (552,589)
# [Frame 695/43149] Zoom: 3.40 Center: (544,591)
# [Frame 696/43149] Zoom: 3.40 Center: (536,593)
# [Frame 697/43149] Zoom: 3.40 Center: (529,599)
# [Frame 698/43149] Zoom: 3.40 Center: (526,604)
# [Frame 699/43149] Zoom: 3.40 Center: (523,608)
# [Frame 700/43149] Zoom: 3.40 Center: (550,613)
# [Frame 701/43149] Zoom: 3.40 Center: (633,617)
# [Frame 702/43149] Zoom: 3.40 Center: (696,620)
# [Frame 703/43149] Zoom: 3.40 Center: (741,623)
# [Frame 704/43149] Zoom: 3.40 Center: (772,625)
# [Frame 705/43149] Zoom: 3.40 Center: (792,626)
# [Frame 706/43149] Zoom: 3.40 Center: (805,627)
#
# Scene 15/224 frames 692-737: tracking classes ['person']
# [Frame 707/43149] Zoom: 3.40 Center: (813,628)
# [Frame 708/43149] Zoom: 3.40 Center: (817,629)
# [Frame 709/43149] Zoom: 3.40 Center: (818,630)
# [Frame 710/43149] Zoom: 3.40 Center: (817,630)
# [Frame 711/43149] Zoom: 3.40 Center: (814,630)
# [Frame 712/43149] Zoom: 3.40 Center: (809,631)
# [Frame 713/43149] Zoom: 3.40 Center: (803,631)
# [Frame 714/43149] Zoom: 3.40 Center: (796,631)
# [Frame 715/43149] Zoom: 3.40 Center: (788,631)
# [Frame 716/43149] Zoom: 3.40 Center: (779,631)
# [Frame 717/43149] Zoom: 3.40 Center: (769,631)
# [Frame 718/43149] Zoom: 3.40 Center: (759,631)
# [Frame 719/43149] Zoom: 3.40 Center: (749,631)
# [Frame 720/43149] Zoom: 3.40 Center: (738,631)
# [Frame 721/43149] Zoom: 3.40 Center: (727,631)
# [Frame 722/43149] Zoom: 3.40 Center: (716,631)
# [Frame 723/43149] Zoom: 3.40 Center: (638,651)
# [Frame 724/43149] Zoom: 3.40 Center: (549,663)
# [Frame 725/43149] Zoom: 3.40 Center: (472,673)
# [Frame 726/43149] Zoom: 3.40 Center: (454,674)
# [Frame 727/43149] Zoom: 3.40 Center: (439,674)
# [Frame 728/43149] Zoom: 3.40 Center: (427,674)
# [Frame 729/43149] Zoom: 3.40 Center: (417,674)
# [Frame 730/43149] Zoom: 3.40 Center: (409,674)
# [Frame 731/43149] Zoom: 3.40 Center: (402,674)
# [Frame 732/43149] Zoom: 3.40 Center: (397,674)
# [Frame 733/43149] Zoom: 3.40 Center: (373,676)
# [Frame 734/43149] Zoom: 3.40 Center: (356,677)
# [Frame 735/43149] Zoom: 3.40 Center: (344,678)
# [Frame 736/43149] Zoom: 3.40 Center: (565,661)
# [Frame 737/43149] Zoom: 3.40 Center: (753,648)
# [Frame 738/43149] Zoom: 3.40 Center: (915,637)
# [Frame 739/43149] Zoom: 3.40 Center: (1056,628)
# [Frame 740/43149] Zoom: 3.40 Center: (1180,621)
# [Frame 741/43149] Zoom: 3.40 Center: (1291,615)
# [Frame 742/43149] Zoom: 3.40 Center: (1391,610)
# [Frame 743/43149] Zoom: 3.40 Center: (1483,605)
# [Frame 744/43149] Zoom: 3.40 Center: (1568,601)
# [Frame 745/43149] Zoom: 3.40 Center: (1647,598)
# [Frame 746/43149] Zoom: 3.40 Center: (1722,595)
# [Frame 747/43149] Zoom: 3.40 Center: (1793,593)
# [Frame 748/43149] Zoom: 3.40 Center: (1862,591)
# [Frame 749/43149] Zoom: 3.40 Center: (1928,589)
# [Frame 750/43149] Zoom: 3.40 Center: (1993,587)
# [Frame 751/43149] Zoom: 3.40 Center: (2056,585)
# [Frame 752/43149] Zoom: 3.40 Center: (2118,584)
#
# Scene 16/224 frames 737-753: tracking classes ['person', 'car']
# [Frame 753/43149] Zoom: 3.40 Center: (2179,583)
# [Frame 754/43149] Zoom: 3.40 Center: (2239,582)
# [Frame 755/43149] Zoom: 3.40 Center: (2147,577)
# [Frame 756/43149] Zoom: 3.40 Center: (2069,572)
# [Frame 757/43149] Zoom: 3.40 Center: (1819,564)
# [Frame 758/43149] Zoom: 3.40 Center: (1599,558)
# [Frame 759/43149] Zoom: 3.40 Center: (1403,552)
# [Frame 760/43149] Zoom: 3.40 Center: (1283,544)
# [Frame 761/43149] Zoom: 3.40 Center: (1225,521)
# [Frame 762/43149] Zoom: 3.40 Center: (1171,503)
# [Frame 763/43149] Zoom: 3.40 Center: (1121,489)
# [Frame 764/43149] Zoom: 3.40 Center: (1075,478)
# [Frame 765/43149] Zoom: 3.39 Center: (1031,469)
# [Frame 766/43149] Zoom: 3.37 Center: (989,462)
# [Frame 767/43149] Zoom: 3.35 Center: (949,456)
# [Frame 768/43149] Zoom: 3.32 Center: (910,451)
# [Frame 769/43149] Zoom: 3.28 Center: (873,447)
#
# Scene 17/224 frames 753-787: tracking classes ['person']
# [Frame 770/43149] Zoom: 3.25 Center: (836,444)
# [Frame 771/43149] Zoom: 3.21 Center: (800,442)
# [Frame 772/43149] Zoom: 3.18 Center: (764,440)
# [Frame 773/43149] Zoom: 3.14 Center: (729,439)
# [Frame 774/43149] Zoom: 3.12 Center: (694,438)
# [Frame 775/43149] Zoom: 3.09 Center: (659,437)
# [Frame 776/43149] Zoom: 3.07 Center: (625,436)
# [Frame 777/43149] Zoom: 3.06 Center: (591,436)
# [Frame 778/43149] Zoom: 3.05 Center: (557,436)
# [Frame 779/43149] Zoom: 3.04 Center: (523,436)
# [Frame 780/43149] Zoom: 3.03 Center: (489,436)
# [Frame 781/43149] Zoom: 3.02 Center: (455,436)
# [Frame 782/43149] Zoom: 3.02 Center: (421,436)
# [Frame 783/43149] Zoom: 3.02 Center: (388,436)
# [Frame 784/43149] Zoom: 3.01 Center: (354,436)
# [Frame 785/43149] Zoom: 3.01 Center: (321,436)
# [Frame 786/43149] Zoom: 3.09 Center: (510,430)
# [Frame 787/43149] Zoom: 3.15 Center: (661,426)
# [Frame 788/43149] Zoom: 3.20 Center: (789,423)
# [Frame 789/43149] Zoom: 3.24 Center: (892,421)
# [Frame 790/43149] Zoom: 3.27 Center: (983,427)
# [Frame 791/43149] Zoom: 3.30 Center: (1057,432)
# [Frame 792/43149] Zoom: 3.32 Center: (1117,436)
# [Frame 793/43149] Zoom: 3.33 Center: (1166,440)
# [Frame 794/43149] Zoom: 3.35 Center: (1207,443)
# [Frame 795/43149] Zoom: 3.36 Center: (1241,446)
# [Frame 796/43149] Zoom: 3.37 Center: (1269,448)
# [Frame 797/43149] Zoom: 3.37 Center: (1292,450)
# [Frame 798/43149] Zoom: 3.38 Center: (1311,452)
# [Frame 799/43149] Zoom: 3.38 Center: (1326,454)
# [Frame 800/43149] Zoom: 3.39 Center: (1332,472)
# [Frame 801/43149] Zoom: 3.39 Center: (1337,487)
# [Frame 802/43149] Zoom: 3.39 Center: (1340,499)
# [Frame 803/43149] Zoom: 3.39 Center: (1342,508)
# [Frame 804/43149] Zoom: 3.39 Center: (1342,516)
#
# Scene 18/224 frames 787-842: tracking classes ['person', 'car']
# [Frame 805/43149] Zoom: 3.40 Center: (1340,523)
# [Frame 806/43149] Zoom: 3.40 Center: (1337,528)
# [Frame 807/43149] Zoom: 3.40 Center: (1268,514)
# [Frame 808/43149] Zoom: 3.40 Center: (1208,503)
# [Frame 809/43149] Zoom: 3.40 Center: (1156,494)
# [Frame 810/43149] Zoom: 3.40 Center: (1112,487)
# [Frame 811/43149] Zoom: 3.40 Center: (1052,473)
# [Frame 812/43149] Zoom: 3.40 Center: (998,462)
# [Frame 813/43149] Zoom: 3.40 Center: (949,453)
# [Frame 814/43149] Zoom: 3.40 Center: (947,438)
# [Frame 815/43149] Zoom: 3.40 Center: (940,427)
# [Frame 816/43149] Zoom: 3.40 Center: (901,415)
# [Frame 817/43149] Zoom: 3.40 Center: (865,406)
# [Frame 818/43149] Zoom: 3.40 Center: (832,399)
# [Frame 819/43149] Zoom: 3.40 Center: (773,386)
# [Frame 820/43149] Zoom: 3.40 Center: (720,376)
# [Frame 821/43149] Zoom: 3.40 Center: (672,368)
# [Frame 822/43149] Zoom: 3.40 Center: (628,362)
# [Frame 823/43149] Zoom: 3.40 Center: (588,357)
# [Frame 824/43149] Zoom: 3.40 Center: (551,353)
# [Frame 825/43149] Zoom: 3.40 Center: (517,351)
# [Frame 826/43149] Zoom: 3.40 Center: (476,348)
# [Frame 827/43149] Zoom: 3.40 Center: (439,346)
# [Frame 828/43149] Zoom: 3.40 Center: (421,343)
# [Frame 829/43149] Zoom: 3.40 Center: (388,343)
# [Frame 830/43149] Zoom: 3.40 Center: (358,343)
# [Frame 831/43149] Zoom: 3.40 Center: (330,344)
# [Frame 832/43149] Zoom: 3.40 Center: (304,345)
# [Frame 833/43149] Zoom: 3.40 Center: (280,346)
# [Frame 834/43149] Zoom: 3.40 Center: (258,348)
# [Frame 835/43149] Zoom: 3.40 Center: (237,350)
# [Frame 836/43149] Zoom: 3.40 Center: (216,352)
# [Frame 837/43149] Zoom: 3.40 Center: (196,354)
# [Frame 838/43149] Zoom: 3.40 Center: (177,356)
# [Frame 839/43149] Zoom: 3.40 Center: (158,358)
# [Frame 840/43149] Zoom: 3.40 Center: (140,360)
# [Frame 841/43149] Zoom: 3.40 Center: (122,362)
# [Frame 842/43149] Zoom: 3.40 Center: (105,364)
# [Frame 843/43149] Zoom: 3.40 Center: (89,366)
# [Frame 844/43149] Zoom: 3.40 Center: (108,372)
# [Frame 845/43149] Zoom: 3.40 Center: (121,377)
# [Frame 846/43149] Zoom: 3.40 Center: (129,381)
# [Frame 847/43149] Zoom: 3.40 Center: (154,380)
# [Frame 848/43149] Zoom: 3.40 Center: (172,380)
# [Frame 849/43149] Zoom: 3.40 Center: (184,380)
# [Frame 850/43149] Zoom: 3.40 Center: (251,387)
# [Frame 851/43149] Zoom: 3.40 Center: (303,393)
# [Frame 852/43149] Zoom: 3.40 Center: (344,398)
# [Frame 853/43149] Zoom: 3.40 Center: (375,403)
# [Frame 854/43149] Zoom: 3.40 Center: (399,407)
# [Frame 855/43149] Zoom: 3.40 Center: (417,411)
# [Frame 856/43149] Zoom: 3.40 Center: (431,414)
# [Frame 857/43149] Zoom: 3.40 Center: (441,417)
# [Frame 858/43149] Zoom: 3.40 Center: (448,420)
# [Frame 859/43149] Zoom: 3.40 Center: (452,423)
# [Frame 860/43149] Zoom: 3.40 Center: (454,426)
#
# Scene 19/224 frames 842-860: tracking classes ['person']
# [Frame 861/43149] Zoom: 3.40 Center: (455,428)
# [Frame 862/43149] Zoom: 3.40 Center: (454,430)
# [Frame 863/43149] Zoom: 3.40 Center: (497,428)
# [Frame 864/43149] Zoom: 3.40 Center: (530,426)
# [Frame 865/43149] Zoom: 3.40 Center: (556,425)
# [Frame 866/43149] Zoom: 3.40 Center: (576,424)
# [Frame 867/43149] Zoom: 3.40 Center: (591,424)
# [Frame 868/43149] Zoom: 3.40 Center: (602,424)
# [Frame 869/43149] Zoom: 3.40 Center: (610,424)
# [Frame 870/43149] Zoom: 3.40 Center: (615,424)
# [Frame 871/43149] Zoom: 3.40 Center: (619,424)
# [Frame 872/43149] Zoom: 3.40 Center: (621,425)
# [Frame 873/43149] No subjects detected
# [Frame 874/43149] No subjects detected
# [Frame 875/43149] No subjects detected
# [Frame 876/43149] No subjects detected
# [Frame 877/43149] No subjects detected
# [Frame 878/43149] No subjects detected
# [Frame 879/43149] No subjects detected
#
# Scene 20/224 frames 860-952: tracking classes ['person', 'car']
# [Frame 880/43149] No subjects detected
# [Frame 881/43149] No subjects detected
# [Frame 882/43149] No subjects detected
# [Frame 883/43149] No subjects detected
# [Frame 884/43149] No subjects detected
# [Frame 885/43149] No subjects detected
# [Frame 886/43149] No subjects detected
# [Frame 887/43149] No subjects detected
# [Frame 888/43149] No subjects detected
# [Frame 889/43149] No subjects detected
# [Frame 890/43149] No subjects detected
# [Frame 891/43149] No subjects detected
# [Frame 892/43149] No subjects detected
# [Frame 893/43149] No subjects detected
# [Frame 894/43149] No subjects detected
# [Frame 895/43149] No subjects detected
# [Frame 896/43149] No subjects detected
# [Frame 897/43149] No subjects detected
# [Frame 898/43149] No subjects detected
# [Frame 899/43149] No subjects detected
# [Frame 900/43149] No subjects detected
# [Frame 901/43149] No subjects detected
# [Frame 902/43149] No subjects detected
# [Frame 903/43149] No subjects detected
# [Frame 904/43149] No subjects detected
# [Frame 905/43149] No subjects detected
# [Frame 906/43149] No subjects detected
# [Frame 907/43149] No subjects detected
# [Frame 908/43149] No subjects detected
# [Frame 909/43149] No subjects detected
# [Frame 910/43149] No subjects detected
# [Frame 911/43149] No subjects detected
# [Frame 912/43149] No subjects detected
# [Frame 913/43149] No subjects detected
# [Frame 914/43149] No subjects detected
# [Frame 915/43149] No subjects detected
# [Frame 916/43149] No subjects detected
# [Frame 917/43149] No subjects detected
# [Frame 918/43149] No subjects detected
# [Frame 919/43149] No subjects detected
# [Frame 920/43149] No subjects detected
# [Frame 921/43149] No subjects detected
# [Frame 922/43149] Zoom: 3.40 Center: (666,481)
# [Frame 923/43149] Zoom: 3.40 Center: (716,523)
# [Frame 924/43149] Zoom: 3.40 Center: (772,554)
# [Frame 925/43149] Zoom: 3.40 Center: (816,578)
# [Frame 926/43149] Zoom: 3.40 Center: (841,599)
# [Frame 927/43149] Zoom: 3.40 Center: (856,617)
# [Frame 928/43149] Zoom: 3.40 Center: (872,632)
# [Frame 929/43149] Zoom: 3.40 Center: (889,644)
# [Frame 930/43149] Zoom: 3.40 Center: (906,654)
# [Frame 931/43149] Zoom: 3.40 Center: (924,662)
# [Frame 932/43149] Zoom: 3.40 Center: (942,669)
# [Frame 933/43149] Zoom: 3.40 Center: (961,674)
# [Frame 934/43149] Zoom: 3.40 Center: (980,678)
# [Frame 935/43149] Zoom: 3.40 Center: (999,682)
# [Frame 936/43149] Zoom: 3.40 Center: (1019,685)
# [Frame 937/43149] Zoom: 3.40 Center: (1039,688)
# [Frame 938/43149] Zoom: 3.40 Center: (1059,690)
# [Frame 939/43149] Zoom: 3.40 Center: (1079,692)
# [Frame 940/43149] Zoom: 3.40 Center: (1099,694)
# [Frame 941/43149] Zoom: 3.40 Center: (1119,696)
# [Frame 942/43149] Zoom: 3.40 Center: (1139,697)
# [Frame 943/43149] Zoom: 3.40 Center: (1159,698)
# [Frame 944/43149] Zoom: 3.40 Center: (1179,699)
# [Frame 945/43149] Zoom: 3.40 Center: (1199,700)
# [Frame 946/43149] Zoom: 3.40 Center: (1219,701)
# [Frame 947/43149] Zoom: 3.40 Center: (1239,702)
# [Frame 948/43149] Zoom: 3.40 Center: (1259,703)
# [Frame 949/43149] Zoom: 3.40 Center: (1279,704)
# [Frame 950/43149] Zoom: 3.40 Center: (1299,705)
# [Frame 951/43149] Zoom: 3.40 Center: (1319,706)
# [Frame 952/43149] Zoom: 3.40 Center: (1339,707)
# [Frame 953/43149] Zoom: 3.40 Center: (1359,708)
# [Frame 954/43149] Zoom: 3.40 Center: (1379,709)
# [Frame 955/43149] Zoom: 3.40 Center: (1341,685)
# [Frame 956/43149] Zoom: 3.40 Center: (1312,665)
# [Frame 957/43149] Zoom: 3.40 Center: (1291,649)
# [Frame 958/43149] Zoom: 3.40 Center: (1242,622)
# [Frame 959/43149] Zoom: 3.40 Center: (1203,600)
# [Frame 960/43149] Zoom: 3.40 Center: (1171,582)
# [Frame 961/43149] Zoom: 3.40 Center: (1146,567)
# [Frame 962/43149] Zoom: 3.40 Center: (1180,559)
# [Frame 963/43149] Zoom: 3.40 Center: (1207,553)
# [Frame 964/43149] Zoom: 3.40 Center: (1229,548)
# [Frame 965/43149] Zoom: 3.40 Center: (1248,544)
# [Frame 966/43149] Zoom: 3.40 Center: (1263,540)
# [Frame 967/43149] Zoom: 3.40 Center: (1275,537)
# [Frame 968/43149] Zoom: 3.40 Center: (1284,536)
# [Frame 969/43149] Zoom: 3.40 Center: (1291,535)
# [Frame 970/43149] Zoom: 3.40 Center: (1297,534)
# [Frame 971/43149] Zoom: 3.40 Center: (1302,533)
# [Frame 972/43149] Zoom: 3.40 Center: (1307,532)
#
# Scene 21/224 frames 952-981: tracking classes ['person']
# [Frame 973/43149] Zoom: 3.40 Center: (1310,531)
# [Frame 974/43149] Zoom: 3.40 Center: (1313,530)
# [Frame 975/43149] Zoom: 3.40 Center: (1315,529)
# [Frame 976/43149] Zoom: 3.40 Center: (1317,528)
# [Frame 977/43149] Zoom: 3.40 Center: (1319,526)
# [Frame 978/43149] Zoom: 3.40 Center: (1339,519)
# [Frame 979/43149] Zoom: 3.40 Center: (1355,513)
# [Frame 980/43149] Zoom: 3.40 Center: (1368,508)
# [Frame 981/43149] Zoom: 3.40 Center: (1378,503)
# [Frame 982/43149] Zoom: 3.39 Center: (1386,499)
# [Frame 983/43149] Zoom: 3.39 Center: (1392,496)
# [Frame 984/43149] Zoom: 3.38 Center: (1397,493)
# [Frame 985/43149] Zoom: 3.37 Center: (1401,490)
# [Frame 986/43149] Zoom: 3.37 Center: (1404,488)
# [Frame 987/43149] Zoom: 3.36 Center: (1407,486)
# [Frame 988/43149] Zoom: 3.35 Center: (1415,482)
# [Frame 989/43149] Zoom: 3.34 Center: (1416,480)
# [Frame 990/43149] Zoom: 3.33 Center: (1416,479)
# [Frame 991/43149] Zoom: 3.33 Center: (1416,478)
# [Frame 992/43149] Zoom: 3.32 Center: (1416,476)
# [Frame 993/43149] Zoom: 3.30 Center: (1390,466)
# [Frame 994/43149] Zoom: 3.29 Center: (1369,458)
# [Frame 995/43149] Zoom: 3.28 Center: (1353,451)
# [Frame 996/43149] Zoom: 3.30 Center: (1385,444)
# [Frame 997/43149] Zoom: 3.32 Center: (1411,438)
# [Frame 998/43149] Zoom: 3.34 Center: (1431,432)
# [Frame 999/43149] Zoom: 3.35 Center: (1447,427)
# [Frame 1000/43149] Zoom: 3.36 Center: (1459,423)
# [Frame 1001/43149] Zoom: 3.37 Center: (1468,419)
# [Frame 1002/43149] Zoom: 3.37 Center: (1475,416)
#
# Scene 22/224 frames 981-999: tracking classes ['person', 'car']
# [Frame 1003/43149] Zoom: 3.38 Center: (1481,413)
# [Frame 1004/43149] Zoom: 3.38 Center: (1525,398)
# [Frame 1005/43149] Zoom: 3.39 Center: (1559,386)
# [Frame 1006/43149] Zoom: 3.39 Center: (1429,385)
# [Frame 1007/43149] Zoom: 3.39 Center: (1323,386)
# [Frame 1008/43149] Zoom: 3.39 Center: (1235,389)
# [Frame 1009/43149] Zoom: 3.39 Center: (1082,400)
# [Frame 1010/43149] Zoom: 3.40 Center: (958,410)
# [Frame 1011/43149] Zoom: 3.40 Center: (858,420)
# [Frame 1012/43149] Zoom: 3.40 Center: (777,429)
# [Frame 1013/43149] Zoom: 3.40 Center: (719,431)
# [Frame 1014/43149] Zoom: 3.40 Center: (672,433)
# [Frame 1015/43149] Zoom: 3.40 Center: (633,436)
# [Frame 1016/43149] Zoom: 3.40 Center: (602,439)
# [Frame 1017/43149] Zoom: 3.40 Center: (577,442)
# [Frame 1018/43149] Zoom: 3.40 Center: (555,445)
# [Frame 1019/43149] Zoom: 3.40 Center: (537,448)
# [Frame 1020/43149] Zoom: 3.40 Center: (522,451)
# [Frame 1021/43149] Zoom: 3.40 Center: (510,454)
#
# Scene 23/224 frames 999-1059: tracking classes ['person']
# [Frame 1022/43149] Zoom: 3.40 Center: (500,457)
# [Frame 1023/43149] Zoom: 3.40 Center: (491,460)
# [Frame 1024/43149] Zoom: 3.40 Center: (483,463)
# [Frame 1025/43149] Zoom: 3.40 Center: (476,466)
# [Frame 1026/43149] Zoom: 3.40 Center: (470,469)
# [Frame 1027/43149] Zoom: 3.40 Center: (465,473)
# [Frame 1028/43149] Zoom: 3.40 Center: (460,476)
# [Frame 1029/43149] Zoom: 3.40 Center: (455,480)
# [Frame 1030/43149] Zoom: 3.40 Center: (451,484)
# [Frame 1031/43149] Zoom: 3.40 Center: (447,488)
# ...
# [Frame 3038/43149] Zoom: 3.40 Center: (1016,582)
# [Frame 3039/43149] Zoom: 3.40 Center: (1015,581)
# [Frame 3040/43149] Zoom: 3.40 Center: (1014,581)
# [Frame 3041/43149] Zoom: 3.40 Center: (1013,580)
# [Frame 3042/43149] Zoom: 3.40 Center: (1012,579)
# [Frame 3043/43149] Zoom: 3.40 Center: (1011,579)
# [Frame 3044/43149] Zoom: 3.40 Center: (1009,578)
# [Frame 3045/43149] Zoom: 3.40 Center: (1008,578)
# [Frame 3046/43149] Zoom: 3.40 Center: (1007,577)
# [Frame 3047/43149] Zoom: 3.40 Center: (1006,576)
# [Frame 3048/43149] Zoom: 3.40 Center: (1005,576)
# [Frame 3049/43149] Zoom: 3.40 Center: (1004,575)
# [Frame 3050/43149] Zoom: 3.40 Center: (1003,574)
# [Frame 3051/43149] Zoom: 3.40 Center: (1002,574)
# [Frame 3052/43149] No subjects detected
# [Frame 3053/43149] No subjects detected
# [Frame 3054/43149] No subjects detected
# [Frame 3055/43149] No subjects detected
# [Frame 3056/43149] No subjects detected
# [Frame 3057/43149] No subjects detected
# [Frame 3058/43149] No subjects detected
# [Frame 3059/43149] No subjects detected
# [Frame 3060/43149] No subjects detected
# [Frame 3061/43149] No subjects detected
# [Frame 3062/43149] No subjects detected
# [Frame 3063/43149] No subjects detected
# [Frame 3064/43149] No subjects detected
# [Frame 3065/43149] No subjects detected
# [Frame 3066/43149] No subjects detected
# [Frame 3067/43149] No subjects detected
# [Frame 3068/43149] No subjects detected
# [Frame 3069/43149] No subjects detected
# [Frame 3070/43149] No subjects detected
# [Frame 3071/43149] No subjects detected
# [Frame 3072/43149] No subjects detected
# [Frame 3073/43149] No subjects detected
# [Frame 3074/43149] No subjects detected
#
# Scene 54/224 frames 3021-3053: tracking classes ['person', 'car']
# [Frame 3075/43149] No subjects detected
# [Frame 3076/43149] No subjects detected
# [Frame 3077/43149] Zoom: 3.40 Center: (914,597)
# [Frame 3078/43149] Zoom: 3.40 Center: (841,616)
# [Frame 3079/43149] Zoom: 3.40 Center: (780,631)
# [Frame 3080/43149] Zoom: 3.40 Center: (731,642)
# [Frame 3081/43149] Zoom: 3.40 Center: (689,650)
# [Frame 3082/43149] Zoom: 3.40 Center: (648,654)
# [Frame 3083/43149] Zoom: 3.40 Center: (607,655)
# [Frame 3084/43149] Zoom: 3.40 Center: (566,655)
# [Frame 3085/43149] Zoom: 3.40 Center: (527,654)
# [Frame 3086/43149] Zoom: 3.40 Center: (491,653)
# [Frame 3087/43149] Zoom: 3.40 Center: (457,650)
# [Frame 3088/43149] Zoom: 3.40 Center: (422,646)
# [Frame 3089/43149] Zoom: 3.40 Center: (383,642)
# [Frame 3090/43149] Zoom: 3.40 Center: (344,638)
# [Frame 3091/43149] Zoom: 3.40 Center: (306,638)
# [Frame 3092/43149] Zoom: 3.40 Center: (268,641)
# [Frame 3093/43149] Zoom: 3.40 Center: (231,643)
# [Frame 3094/43149] Zoom: 3.40 Center: (195,645)
# [Frame 3095/43149] Zoom: 3.40 Center: (159,647)
# [Frame 3096/43149] Zoom: 3.40 Center: (124,649)
# [Frame 3097/43149] Zoom: 3.40 Center: (89,650)
# [Frame 3098/43149] Zoom: 3.40 Center: (303,655)
# [Frame 3099/43149] Zoom: 3.40 Center: (471,659)
# [Frame 3100/43149] Zoom: 3.40 Center: (603,662)
# [Frame 3101/43149] Zoom: 3.40 Center: (705,664)
# [Frame 3102/43149] Zoom: 3.40 Center: (784,666)
# [Frame 3103/43149] Zoom: 3.40 Center: (864,668)
# [Frame 3104/43149] Zoom: 3.40 Center: (927,670)
# [Frame 3105/43149] Zoom: 3.40 Center: (976,672)
# [Frame 3106/43149] Zoom: 3.40 Center: (1014,673)
# [Frame 3107/43149] Zoom: 3.40 Center: (1043,674)
#
# Scene 55/224 frames 3053-3122: tracking classes ['person']
# [Frame 3108/43149] Zoom: 3.40 Center: (1065,675)
# [Frame 3109/43149] Zoom: 3.40 Center: (1081,675)
# [Frame 3110/43149] Zoom: 3.40 Center: (1092,675)
# [Frame 3111/43149] Zoom: 3.40 Center: (1099,675)
# [Frame 3112/43149] Zoom: 3.40 Center: (1103,675)
# [Frame 3113/43149] Zoom: 3.40 Center: (1189,676)
# [Frame 3114/43149] Zoom: 3.40 Center: (1172,676)
# [Frame 3115/43149] Zoom: 3.40 Center: (1157,676)
# [Frame 3116/43149] Zoom: 3.40 Center: (1143,676)
# [Frame 3117/43149] Zoom: 3.40 Center: (1130,676)
# [Frame 3118/43149] Zoom: 3.40 Center: (1118,676)
# [Frame 3119/43149] Zoom: 3.40 Center: (1107,676)
# [Frame 3120/43149] Zoom: 3.40 Center: (1097,676)
# [Frame 3121/43149] Zoom: 3.40 Center: (1087,675)
# [Frame 3122/43149] Zoom: 3.40 Center: (1077,675)
# [Frame 3123/43149] Zoom: 3.40 Center: (1164,675)
# [Frame 3124/43149] Zoom: 3.40 Center: (1239,669)
# [Frame 3125/43149] Zoom: 3.40 Center: (1302,664)
# [Frame 3126/43149] Zoom: 3.40 Center: (1356,660)
# [Frame 3127/43149] Zoom: 3.40 Center: (1402,657)
# [Frame 3128/43149] Zoom: 3.40 Center: (1442,655)
# [Frame 3129/43149] Zoom: 3.40 Center: (1477,653)
# [Frame 3130/43149] Zoom: 3.40 Center: (1508,651)
# [Frame 3131/43149] Zoom: 3.40 Center: (1536,649)
# [Frame 3132/43149] Zoom: 3.40 Center: (1562,648)
# [Frame 3133/43149] Zoom: 3.40 Center: (1586,647)
# [Frame 3134/43149] Zoom: 3.40 Center: (1617,649)
# [Frame 3135/43149] Zoom: 3.40 Center: (1670,648)
# [Frame 3136/43149] Zoom: 3.40 Center: (1718,647)
# [Frame 3137/43149] Zoom: 3.40 Center: (1762,647)
# [Frame 3138/43149] Zoom: 3.40 Center: (1981,623)
# [Frame 3139/43149] Zoom: 3.40 Center: (2173,604)
# [Frame 3140/43149] Zoom: 3.40 Center: (2344,589)
# [Frame 3141/43149] Zoom: 3.40 Center: (2498,576)
# [Frame 3142/43149] Zoom: 3.40 Center: (2638,566)
# [Frame 3143/43149] Zoom: 3.40 Center: (2767,558)
# [Frame 3144/43149] Zoom: 3.40 Center: (2887,551)
# [Frame 3145/43149] Zoom: 3.40 Center: (3000,546)
# [Frame 3146/43149] Zoom: 3.40 Center: (3108,542)
# [Frame 3147/43149] Zoom: 3.40 Center: (3211,538)
# [Frame 3148/43149] Zoom: 3.40 Center: (3311,535)
# [Frame 3149/43149] Zoom: 3.40 Center: (3408,533)
# [Frame 3150/43149] Zoom: 3.40 Center: (3502,531)
# [Frame 3151/43149] Zoom: 3.40 Center: (3595,529)
# [Frame 3152/43149] Zoom: 3.40 Center: (3686,527)
# [Frame 3153/43149] Zoom: 3.40 Center: (3776,526)
# [Frame 3154/43149] Zoom: 3.40 Center: (3865,525)
# [Frame 3155/43149] Zoom: 3.40 Center: (3953,524)
# [Frame 3156/43149] No subjects detected
# [Frame 3157/43149] No subjects detected
# [Frame 3158/43149] No subjects detected
# [Frame 3159/43149] No subjects detected
# [Frame 3160/43149] No subjects detected
# [Frame 3161/43149] No subjects detected
# [Frame 3162/43149] No subjects detected
# [Frame 3163/43149] No subjects detected
# [Frame 3164/43149] No subjects detected
# [Frame 3165/43149] No subjects detected
# [Frame 3166/43149] No subjects detected
# [Frame 3167/43149] No subjects detected
# [Frame 3168/43149] No subjects detected
# [Frame 3169/43149] No subjects detected
# [Frame 3170/43149] No subjects detected
# [Frame 3171/43149] No subjects detected
# [Frame 3172/43149] No subjects detected
# [Frame 3173/43149] No subjects detected
# [Frame 3174/43149] No subjects detected
# [Frame 3175/43149] No subjects detected
# [Frame 3176/43149] No subjects detected
# [Frame 3177/43149] No subjects detected
#
# Scene 56/224 frames 3122-3146: tracking classes ['person', 'car']
# [Frame 3178/43149] No subjects detected
# [Frame 3179/43149] No subjects detected
# [Frame 3180/43149] Zoom: 3.40 Center: (3402,557)
# [Frame 3181/43149] Zoom: 3.40 Center: (2962,585)
# [Frame 3182/43149] Zoom: 3.40 Center: (2612,606)
# [Frame 3183/43149] Zoom: 3.40 Center: (2334,620)
# [Frame 3184/43149] Zoom: 3.40 Center: (2114,628)
# [Frame 3185/43149] Zoom: 3.40 Center: (1940,634)
# [Frame 3186/43149] Zoom: 3.40 Center: (1802,647)
# [Frame 3187/43149] Zoom: 3.40 Center: (1692,668)
# [Frame 3188/43149] Zoom: 3.40 Center: (1604,692)
# [Frame 3189/43149] Zoom: 3.40 Center: (1534,716)
# [Frame 3190/43149] Zoom: 3.40 Center: (1480,731)
# [Frame 3191/43149] Zoom: 3.40 Center: (1440,734)
# [Frame 3192/43149] Zoom: 3.40 Center: (1409,729)
# [Frame 3193/43149] Zoom: 3.40 Center: (1404,720)
# [Frame 3194/43149] Zoom: 3.40 Center: (1403,712)
# [Frame 3195/43149] Zoom: 3.40 Center: (1406,705)
# [Frame 3196/43149] Zoom: 3.40 Center: (1412,698)
# [Frame 3197/43149] Zoom: 3.40 Center: (1420,692)
# [Frame 3198/43149] Zoom: 3.40 Center: (1409,688)
# [Frame 3199/43149] Zoom: 3.40 Center: (1412,684)
# [Frame 3200/43149] Zoom: 3.40 Center: (1423,681)
# [Frame 3201/43149] Zoom: 3.40 Center: (1439,678)
# [Frame 3202/43149] Zoom: 3.40 Center: (1459,675)
#
# Scene 57/224 frames 3146-3161: tracking classes ['person']
# [Frame 3203/43149] Zoom: 3.40 Center: (1483,673)
# [Frame 3204/43149] Zoom: 3.40 Center: (1510,671)
# [Frame 3205/43149] Zoom: 3.40 Center: (1397,651)
# [Frame 3206/43149] Zoom: 3.40 Center: (1310,635)
# [Frame 3207/43149] Zoom: 3.40 Center: (1243,623)
# [Frame 3208/43149] Zoom: 3.40 Center: (1182,613)
# [Frame 3209/43149] Zoom: 3.40 Center: (1137,608)
# [Frame 3210/43149] Zoom: 3.40 Center: (1103,604)
# [Frame 3211/43149] Zoom: 3.40 Center: (1078,600)
# [Frame 3212/43149] Zoom: 3.40 Center: (1060,597)
# [Frame 3213/43149] Zoom: 3.40 Center: (1048,595)
# [Frame 3214/43149] Zoom: 3.40 Center: (1040,593)
# [Frame 3215/43149] Zoom: 3.40 Center: (1036,592)
# [Frame 3216/43149] Zoom: 3.40 Center: (1035,591)
# [Frame 3217/43149] Zoom: 3.40 Center: (1036,590)
# [Frame 3218/43149] Zoom: 3.40 Center: (1039,589)
#
# Scene 58/224 frames 3161-3185: tracking classes ['person', 'car']
# [Frame 3219/43149] Zoom: 3.40 Center: (1043,588)
# [Frame 3220/43149] Zoom: 3.40 Center: (1049,587)
# [Frame 3221/43149] Zoom: 3.40 Center: (1032,586)
# [Frame 3222/43149] Zoom: 3.40 Center: (1020,585)
# [Frame 3223/43149] Zoom: 3.40 Center: (1012,585)
# [Frame 3224/43149] Zoom: 3.40 Center: (991,585)
# [Frame 3225/43149] Zoom: 3.40 Center: (975,585)
# [Frame 3226/43149] Zoom: 3.40 Center: (963,585)
# [Frame 3227/43149] Zoom: 3.40 Center: (955,585)
# [Frame 3228/43149] Zoom: 3.40 Center: (949,584)
# [Frame 3229/43149] Zoom: 3.40 Center: (946,584)
# [Frame 3230/43149] Zoom: 3.40 Center: (903,582)
# [Frame 3231/43149] Zoom: 3.40 Center: (869,581)
# [Frame 3232/43149] Zoom: 3.40 Center: (842,580)
# [Frame 3233/43149] Zoom: 3.40 Center: (820,579)
# [Frame 3234/43149] Zoom: 3.40 Center: (803,578)
# [Frame 3235/43149] Zoom: 3.40 Center: (789,577)
# [Frame 3236/43149] Zoom: 3.40 Center: (779,575)
# [Frame 3237/43149] Zoom: 3.40 Center: (771,574)
# [Frame 3238/43149] Zoom: 3.40 Center: (765,573)
# [Frame 3239/43149] Zoom: 3.40 Center: (760,572)
# [Frame 3240/43149] Zoom: 3.40 Center: (756,571)
# [Frame 3241/43149] Zoom: 3.40 Center: (753,570)
# [Frame 3242/43149] Zoom: 3.40 Center: (751,569)
# [Frame 3243/43149] Zoom: 3.40 Center: (749,568)
#
# Scene 59/224 frames 3185-3202: tracking classes ['person']
# [Frame 3244/43149] Zoom: 3.40 Center: (748,567)
# [Frame 3245/43149] Zoom: 3.40 Center: (747,566)
# [Frame 3246/43149] Zoom: 3.40 Center: (747,565)
# [Frame 3247/43149] Zoom: 3.40 Center: (747,564)
# [Frame 3248/43149] Zoom: 3.40 Center: (747,563)
# [Frame 3249/43149] Zoom: 3.40 Center: (747,562)
# [Frame 3250/43149] Zoom: 3.40 Center: (747,561)
# [Frame 3251/43149] Zoom: 3.40 Center: (747,560)
# [Frame 3252/43149] Zoom: 3.40 Center: (747,559)
# [Frame 3253/43149] Zoom: 3.40 Center: (747,558)
# [Frame 3254/43149] Zoom: 3.40 Center: (748,558)
# [Frame 3255/43149] Zoom: 3.40 Center: (751,558)
# [Frame 3256/43149] Zoom: 3.40 Center: (760,559)
# [Frame 3257/43149] Zoom: 3.40 Center: (763,556)
# [Frame 3258/43149] Zoom: 3.40 Center: (766,554)
# [Frame 3259/43149] Zoom: 3.40 Center: (769,552)
# [Frame 3260/43149] Zoom: 3.40 Center: (771,550)
# [Frame 3261/43149] Zoom: 3.40 Center: (777,548)
#
# Scene 60/224 frames 3202-3280: tracking classes ['person', 'car']
# [Frame 3262/43149] Zoom: 3.40 Center: (782,546)
# [Frame 3263/43149] Zoom: 3.40 Center: (788,543)
# [Frame 3264/43149] Zoom: 3.40 Center: (791,546)
# [Frame 3265/43149] Zoom: 3.40 Center: (799,549)
# [Frame 3266/43149] Zoom: 3.40 Center: (806,551)
# [Frame 3267/43149] Zoom: 3.40 Center: (818,554)
# [Frame 3268/43149] Zoom: 3.40 Center: (829,556)
# [Frame 3269/43149] Zoom: 3.40 Center: (837,556)
# [Frame 3270/43149] Zoom: 3.40 Center: (843,556)
# [Frame 3271/43149] Zoom: 3.40 Center: (848,556)
# [Frame 3272/43149] Zoom: 3.40 Center: (853,556)
# [Frame 3273/43149] Zoom: 3.40 Center: (858,556)
# [Frame 3274/43149] Zoom: 3.40 Center: (862,556)
# [Frame 3275/43149] Zoom: 3.40 Center: (865,556)
# [Frame 3276/43149] Zoom: 3.40 Center: (862,554)
# [Frame 3277/43149] Zoom: 3.40 Center: (860,552)
# [Frame 3278/43149] Zoom: 3.40 Center: (859,551)
# [Frame 3279/43149] Zoom: 3.40 Center: (860,550)
# [Frame 3280/43149] Zoom: 3.40 Center: (862,549)
# [Frame 3281/43149] Zoom: 3.40 Center: (864,548)
# [Frame 3282/43149] Zoom: 3.40 Center: (866,547)
# [Frame 3283/43149] Zoom: 3.40 Center: (867,546)
# [Frame 3284/43149] Zoom: 3.40 Center: (868,545)
# [Frame 3285/43149] Zoom: 3.40 Center: (869,544)
# [Frame 3286/43149] Zoom: 3.40 Center: (870,543)
# [Frame 3287/43149] Zoom: 3.40 Center: (870,542)
# [Frame 3288/43149] Zoom: 3.40 Center: (873,541)
# [Frame 3289/43149] Zoom: 3.40 Center: (876,539)
# [Frame 3290/43149] Zoom: 3.40 Center: (879,537)
# [Frame 3291/43149] Zoom: 3.40 Center: (882,535)
# [Frame 3292/43149] Zoom: 3.39 Center: (885,533)
# [Frame 3293/43149] Zoom: 3.38 Center: (890,532)
# [Frame 3294/43149] Zoom: 3.38 Center: (895,531)
# [Frame 3295/43149] Zoom: 3.37 Center: (899,530)
# [Frame 3296/43149] Zoom: 3.37 Center: (903,528)
# [Frame 3297/43149] Zoom: 3.36 Center: (906,526)
# [Frame 3298/43149] Zoom: 3.36 Center: (908,524)
# [Frame 3299/43149] Zoom: 3.35 Center: (910,522)
# [Frame 3300/43149] Zoom: 3.35 Center: (912,520)
# [Frame 3301/43149] Zoom: 3.35 Center: (915,518)
# [Frame 3302/43149] Zoom: 3.35 Center: (916,515)
# [Frame 3303/43149] Zoom: 3.34 Center: (917,513)
# [Frame 3304/43149] Zoom: 3.34 Center: (918,511)
# [Frame 3305/43149] Zoom: 3.34 Center: (917,509)
# [Frame 3306/43149] Zoom: 3.34 Center: (915,508)
# [Frame 3307/43149] Zoom: 3.33 Center: (912,507)
# [Frame 3308/43149] Zoom: 3.33 Center: (910,506)
# [Frame 3309/43149] Zoom: 3.33 Center: (912,503)
# [Frame 3310/43149] Zoom: 3.32 Center: (920,501)
# [Frame 3311/43149] Zoom: 3.22 Center: (1017,483)
# [Frame 3312/43149] Zoom: 3.14 Center: (1100,468)
# [Frame 3313/43149] Zoom: 3.07 Center: (1171,455)
# [Frame 3314/43149] Zoom: 3.01 Center: (1232,443)
# [Frame 3315/43149] Zoom: 2.97 Center: (1284,432)
# [Frame 3316/43149] Zoom: 2.94 Center: (1329,422)
# [Frame 3317/43149] Zoom: 2.91 Center: (1367,412)
# [Frame 3318/43149] Zoom: 3.01 Center: (1280,466)
# [Frame 3319/43149] Zoom: 3.09 Center: (1208,508)
# [Frame 3320/43149] Zoom: 3.15 Center: (1150,542)
# [Frame 3321/43149] Zoom: 3.20 Center: (1161,561)
# [Frame 3322/43149] Zoom: 3.24 Center: (1171,577)
# [Frame 3323/43149] Zoom: 3.27 Center: (1182,590)
# [Frame 3324/43149] Zoom: 3.30 Center: (1192,601)
# [Frame 3325/43149] Zoom: 3.32 Center: (1204,611)
# [Frame 3326/43149] Zoom: 3.33 Center: (1215,619)
# [Frame 3327/43149] Zoom: 3.35 Center: (1226,626)
# [Frame 3328/43149] Zoom: 3.36 Center: (1237,632)
# [Frame 3329/43149] Zoom: 3.37 Center: (1250,638)
# [Frame 3330/43149] Zoom: 3.37 Center: (1263,644)
# [Frame 3331/43149] Zoom: 3.38 Center: (1276,649)
# [Frame 3332/43149] Zoom: 3.38 Center: (1288,654)
# [Frame 3333/43149] Zoom: 3.39 Center: (1272,646)
# [Frame 3334/43149] Zoom: 3.39 Center: (1261,640)
# [Frame 3335/43149] Zoom: 3.39 Center: (1248,636)
# [Frame 3336/43149] Zoom: 3.39 Center: (1238,633)
# [Frame 3337/43149] Zoom: 3.39 Center: (1230,631)
# [Frame 3338/43149] Zoom: 3.40 Center: (1225,630)
# [Frame 3339/43149] Zoom: 3.40 Center: (1213,629)
# [Frame 3340/43149] Zoom: 3.40 Center: (1201,629)
#
# Scene 61/224 frames 3280-3297: tracking classes ['person']
# [Frame 3341/43149] Zoom: 3.40 Center: (1191,630)
# [Frame 3342/43149] Zoom: 3.40 Center: (1184,632)
# [Frame 3343/43149] Zoom: 3.40 Center: (1178,634)
# [Frame 3344/43149] Zoom: 3.40 Center: (1174,636)
# [Frame 3345/43149] Zoom: 3.40 Center: (1170,638)
# [Frame 3346/43149] Zoom: 3.40 Center: (1169,639)
# [Frame 3347/43149] Zoom: 3.40 Center: (1173,640)
# [Frame 3348/43149] Zoom: 3.40 Center: (1177,641)
# [Frame 3349/43149] Zoom: 3.40 Center: (1179,642)
# [Frame 3350/43149] Zoom: 3.40 Center: (1216,634)
# [Frame 3351/43149] Zoom: 3.40 Center: (1246,628)
# [Frame 3352/43149] Zoom: 3.40 Center: (1271,623)
# [Frame 3353/43149] Zoom: 3.40 Center: (1291,619)
# [Frame 3354/43149] Zoom: 3.40 Center: (1307,616)
# [Frame 3355/43149] Zoom: 3.40 Center: (1321,614)
# [Frame 3356/43149] Zoom: 3.40 Center: (1332,613)
# [Frame 3357/43149] Zoom: 3.40 Center: (1263,602)
# [Frame 3358/43149] Zoom: 3.40 Center: (1207,593)
#
# Scene 62/224 frames 3297-3330: tracking classes ['person', 'car']
# [Frame 3359/43149] Zoom: 3.40 Center: (1162,585)
# [Frame 3360/43149] Zoom: 3.40 Center: (1031,566)
# [Frame 3361/43149] Zoom: 3.40 Center: (1034,555)
# [Frame 3362/43149] Zoom: 3.40 Center: (1036,546)
# [Frame 3363/43149] Zoom: 3.40 Center: (1037,538)

# %%
# ======= Full minimal notebook snippet with safe YOLO loading =======

import json
import os
import psutil
import time
import torch
import GPUtil
import platform
from datetime import datetime
import numpy as np
import cv2

# Import Ultralytics YOLO
from ultralytics import YOLO
from ultralytics.nn.tasks import DetectionModel

# Import torch Sequential container and any other needed
from torch.nn.modules.container import Sequential

# Add these classes to PyTorch safe globals for loading weights (PyTorch 2.6+)
torch.serialization.add_safe_globals([DetectionModel, Sequential])

# Import DeepSort tracker
from deep_sort_realtime.deepsort_tracker import DeepSort

# Import PySceneDetect
from scenedetect import VideoManager, SceneManager
from scenedetect.detectors import ContentDetector


# ==== CONFIG ====
CONFIG = {
    "video_path": "/content/drive/MyDrive/Colab Notebooks/input_2.mp4",
    "output_path": "/content/drive/MyDrive/Colab Notebooks/test_output_2.mp4",
    "target_classes": ["person", "car"],
    "yolo_model": "yolov8x.pt",
    "conf_threshold": 0.35,
    "zoom_min": 2.2,
    "zoom_max": 3.4,
    "scene_threshold": 30.0,
    "fps": 24,
    "deep_sort": {
        "max_age": 30,
        "n_init": 3,
        "max_iou_distance": 0.7
    }
}

# ==== INIT MODELS ====
device = "cuda" if torch.cuda.is_available() else "cpu"
model = YOLO(CONFIG["yolo_model"])  # Loads with safe globals patch
model.to(device)

deepsort = DeepSort(
    max_age=CONFIG["deep_sort"]["max_age"],
    n_init=CONFIG["deep_sort"]["n_init"],
    max_iou_distance=CONFIG["deep_sort"]["max_iou_distance"]
)

CLASS_NAME_TO_ID = {name: idx for idx, name in model.names.items()}
TARGET_CLASS_IDS = [CLASS_NAME_TO_ID.get(name) for name in CONFIG["target_classes"] if name in CLASS_NAME_TO_ID]


# ==== UTILS ====
def detect_scenes(video_path, threshold):
    video_manager = VideoManager([video_path])
    scene_manager = SceneManager()
    scene_manager.add_detector(ContentDetector(threshold=threshold))
    video_manager.set_duration()
    video_manager.start()
    scene_manager.detect_scenes(frame_source=video_manager)
    scene_list = scene_manager.get_scene_list()
    video_manager.release()
    return [(int(start.get_frames()), int(end.get_frames())) for start, end in scene_list]


def crop_zoom(frame, center_x, center_y, zoom):
    h, w = frame.shape[:2]
    new_w, new_h = int(w / zoom), int(h / zoom)
    x1, y1 = max(0, center_x - new_w // 2), max(0, center_y - new_h // 2)
    x2, y2 = min(w, x1 + new_w), min(h, y1 + new_h)
    if x2 <= x1 or y2 <= y1:
        return frame
    return cv2.resize(frame[y1:y2, x1:x2], (w, h))


def get_hardware_info():
    gpu_info = GPUtil.getGPUs()[0] if torch.cuda.is_available() else None
    return {
        "cpu_physical_cores": psutil.cpu_count(logical=False),
        "cpu_logical_cores": psutil.cpu_count(logical=True),
        "gpu_name": gpu_info.name if gpu_info else "CPU",
        "gpu_memory_total_mb": gpu_info.memoryTotal if gpu_info else None,
        "ram_total_gb": round(psutil.virtual_memory().total / (1024**3), 2),
        "system": platform.system(),
        "python_version": platform.python_version()
    }


# ==== MAIN PROCESS ====
def process_video():
    hw_info = get_hardware_info()
    cap = cv2.VideoCapture(CONFIG["video_path"])
    width, height = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    writer = cv2.VideoWriter(CONFIG["output_path"], cv2.VideoWriter_fourcc(*"mp4v"), CONFIG["fps"], (width, height))
    scene_frames = detect_scenes(CONFIG["video_path"], CONFIG["scene_threshold"])

    log_data = {
        "hardware": hw_info,
        "parameters": CONFIG,
        "total_scenes": len(scene_frames),
        "total_frames": total_frames,
        "processing_start": datetime.now().isoformat()
    }

    frame_idx = 0
    start_time = time.time()

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        results = model.predict(frame, conf=CONFIG["conf_threshold"], device=device, verbose=False)
        detections = results[0].boxes.data.cpu().numpy()

        track_inputs = []
        for *xyxy, conf, cls in detections:
            if int(cls) in TARGET_CLASS_IDS:
                x1, y1, x2, y2 = map(int, xyxy)
                track_inputs.append(([x1, y1, x2 - x1, y2 - y1], conf, model.names[int(cls)]))

        tracks = deepsort.update_tracks(track_inputs, frame=frame)

        subjects = []
        for track in tracks:
            if not track.is_confirmed():
                continue
            x1, y1, x2, y2 = map(int, track.to_ltrb())
            center_x, center_y = (x1 + x2) // 2, (y1 + y2) // 2
            area_ratio = ((x2 - x1) * (y2 - y1)) / (width * height)
            if area_ratio > 0:
                zoom = np.clip(3.0 / area_ratio, CONFIG["zoom_min"], CONFIG["zoom_max"])
                subjects.append((center_x, center_y, zoom))

        if subjects:
            avg_center_x = int(np.mean([s[0] for s in subjects]))
            avg_center_y = int(np.mean([s[1] for s in subjects]))
            avg_zoom = np.mean([s[2] for s in subjects])
            frame = crop_zoom(frame, avg_center_x, avg_center_y, avg_zoom)

        writer.write(frame)
        frame_idx += 1

    cap.release()
    writer.release()

    elapsed = time.time() - start_time
    log_data["processing_end"] = datetime.now().isoformat()
    log_data["processing_time_sec"] = elapsed
    log_data["avg_fps"] = total_frames / elapsed
    log_data["output_file"] = CONFIG["output_path"]

    with open(f"log_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json", "w") as f:
        json.dump(log_data, f, indent=4)

    print(f"✅ Done in {elapsed:.2f}s, avg FPS: {log_data['avg_fps']:.2f}")


# ==== RUN ====
process_video()
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# /tmp/ipython-input-357654288.py in <cell line: 0>()
#      50 # ==== INIT MODELS ====
#      51 device = "cuda" if torch.cuda.is_available() else "cpu"
# ---> 52 model = YOLO(CONFIG["yolo_model"])  # Loads with safe globals patch
#      53 model.to(device)
#      54
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in __init__(self, model, task)
#      95             self._new(model, task)
#      96         else:
# ---> 97             self._load(model, task)
#      98
#      99     def __call__(self, source=None, stream=False, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in _load(self, weights, task)
#     147         suffix = Path(weights).suffix
#     148         if suffix == '.pt':
# --> 149             self.model, self.ckpt = attempt_load_one_weight(weights)
#     150             self.task = self.model.args['task']
#     151             self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py in attempt_load_one_weight(weight, device, inplace, fuse)
#     626 def attempt_load_one_weight(weight, device=None, inplace=True, fuse=False):
#     627     """Loads a single model weights."""
# --> 628     ckpt, weight = torch_safe_load(weight)  # load ckpt
#     629     args = {**DEFAULT_CFG_DICT, **(ckpt.get('train_args', {}))}  # combine model and default args, preferring model args
#     630     model = (ckpt.get('ema') or ckpt['model']).to(device).float()  # FP32 model
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py in torch_safe_load(weight)
#     565                 'ultralytics.yolo.v8': 'ultralytics.models.yolo',
#     566                 'ultralytics.yolo.data': 'ultralytics.data'}):  # for legacy 8.0 Classify and Pose models
# --> 567             return torch.load(file, map_location='cpu'), file  # load
#     568
#     569     except ModuleNotFoundError as e:  # e.name is missing module name
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1468                         )
#    1469                     except pickle.UnpicklingError as e:
# -> 1470                         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#    1471                 return _load(
#    1472                     opened_zipfile,
#
# UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL ultralytics.nn.modules.Conv was not an allowed global by default. Please use `torch.serialization.add_safe_globals([Conv])` or the `torch.serialization.safe_globals([Conv])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
